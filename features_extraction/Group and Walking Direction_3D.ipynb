# %% [markdown]
# ## Binary output of Group Feature

# %%
import os
import numpy as np
from sklearn.cluster import DBSCAN


def load_label3d(file_path):
    """
    Load 3D labels for pedestrians from the label3d.txt file.

    Args:
        file_path (str): Path to the label3d.txt file.

    Returns:
        dict: Dictionary with pedestrian IDs as keys and 3D coordinates as values.
    """
    pedestrian_positions = {}
    with open(file_path, 'r') as f:
        for line in f.readlines():
            parts = line.strip().split(',')
            if parts[0] == 'Pedestrian':  # Check if the label indicates a pedestrian
                try:
                    ped_id = parts[1]  # Track ID
                    pos_x, pos_y, pos_z = map(float, parts[3:6])  # Extract 3D coordinates
                    pedestrian_positions[ped_id] = (pos_x, pos_y, pos_z)
                except ValueError as e:
                    print(f"Error parsing line: {line} -> {e}")
    return pedestrian_positions


def check_groups_in_3d(scenario_folder, proximity_threshold=5.0):
    """
    Check if each pedestrian is in a group in each frame based on proximity in 3D space.

    Args:
        scenario_folder (str): Path to the folder containing 3D label3d files.
        proximity_threshold (float): Maximum distance (in meters) to consider pedestrians as part of the same group.

    Returns:
        dict: Dictionary containing frame IDs and pedestrian group statuses {pedestrian_id: 1 or 0}.
    """
    # Load all label3d files, sorted by frame number
    label3d_files = sorted([f for f in os.listdir(scenario_folder) if f.startswith("label3d_") and f.endswith(".txt")])

    frames_with_group_status = {}

    for label3d_file in label3d_files:
        try:
            frame_id = int(''.join(filter(str.isdigit, label3d_file.split('_')[1].split('.')[0])))
        except ValueError:
            print(f"Invalid file name: {label3d_file}")
            continue

        label3d_path = os.path.join(scenario_folder, label3d_file)
        pedestrian_positions = load_label3d(label3d_path)
        #print(f"Frame {frame_id}: Parsed Pedestrian Positions: {pedestrian_positions}")

        if not pedestrian_positions:
            frames_with_group_status[frame_id] = {}
            continue

        # Extract pedestrian IDs and coordinates
        pedestrian_ids = list(pedestrian_positions.keys())
        coords = np.array(list(pedestrian_positions.values()))

        # Apply DBSCAN clustering
        clustering = DBSCAN(eps=proximity_threshold, min_samples=2).fit(coords)
        labels = clustering.labels_
        #print(f"Frame {frame_id}: DBSCAN Labels: {labels}")

        # Map labels to pedestrian IDs and assign binary status
        frame_status = {}
        for idx, ped_id in enumerate(pedestrian_ids):
            label = labels[idx]
            if label == -1:
                frame_status[ped_id] = 0  # Not in a group
            else:
                frame_status[ped_id] = 1  # In a group

        frames_with_group_status[frame_id] = frame_status

    return frames_with_group_status

# %%
# Example
scenario_folder = "/content/drive/MyDrive/Loki_Dataset/Loki/scenario_000"
proximity_threshold = 5.0  # Maximum distance in meters
frames_with_group_status = check_groups_in_3d(scenario_folder, proximity_threshold)

# Print frames with pedestrian group status
for frame_id, status_dict in frames_with_group_status.items():
    print(f"Frame {frame_id}:")
    for ped_id, status in status_dict.items():
        print(f"  Pedestrian {ped_id}: {'In a group' if status == 1 else 'Not in a group'}")
# Out:
# Frame 0:
#   Pedestrian 4e34ccd4-5ed8-4155-91d4-9e812477a0fd: Not in a group
#   Pedestrian daab3271-6d82-4e72-84cb-064227f446e9: Not in a group
# Frame 2:
#   Pedestrian 4e34ccd4-5ed8-4155-91d4-9e812477a0fd: In a group
#   Pedestrian daab3271-6d82-4e72-84cb-064227f446e9: In a group
# Frame 4:
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
#   Pedestrian daab3271-6d82-4e72-84cb-064227f446e9: Not in a group
# Frame 6:
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
#   Pedestrian daab3271-6d82-4e72-84cb-064227f446e9: Not in a group
# Frame 8:
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 10:
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 12:
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 14:
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 16:
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 18:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 20:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 22:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 24:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 26:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 28:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 30:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
# Frame 32:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
# Frame 34:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
# Frame 36:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
# Frame 38:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
# Frame 40:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
# Frame 42:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
# Frame 44:
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
# Frame 46:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
# Frame 48:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
# Frame 50:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
# Frame 52:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
# Frame 54:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
# Frame 56:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: Not in a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
# Frame 58:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 60:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 62:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 64:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 66:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 68:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 70:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 72:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 74:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 76:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 78:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: Not in a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 80:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 82:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 84:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5: Not in a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 86:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 88:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 90:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 92:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 94:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 96:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: In a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877: In a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 98:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 100:
#   Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559: Not in a group
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group
# Frame 102:
#   Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf: In a group
#   Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132: Not in a group
#   Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283: In a group
#   Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09: In a group

# %% [markdown]
# ## Extract Walking Directions

# %%
import os
import numpy as np


def load_label3d_positions(scenario_folder):
    """
    Extract pedestrian positions from label3d_*.txt files.

    Args:
        scenario_folder (str): Path to the folder containing label3d_*.txt files.

    Returns:
        dict: Pedestrian positions for each frame {frame_id: {pedestrian_id: (x, y, z)}}.
    """
    label3d_files = sorted([f for f in os.listdir(scenario_folder) if f.startswith("label3d_") and f.endswith(".txt")])
    pedestrian_positions_frames = {}

    for file in label3d_files:
        frame_id = int(''.join(filter(str.isdigit, file.split('_')[1].split('.')[0])))
        pedestrian_positions_frames[frame_id] = {}

        with open(os.path.join(scenario_folder, file), 'r') as f:
            for line in f.readlines():
                parts = line.strip().split(',')
                if parts[0] == "Pedestrian":  # Ensure it's a pedestrian
                    ped_id = parts[1]
                    pos_x, pos_y, pos_z = map(float, parts[3:6])  # Extract position
                    pedestrian_positions_frames[frame_id][ped_id] = (pos_x, pos_y, pos_z)

    return pedestrian_positions_frames

# %%
def load_vehicle_positions(scenario_folder):
    """
    Extract vehicle positions from odom_*.txt files.

    Args:
        scenario_folder (str): Path to the folder containing odom_*.txt files.

    Returns:
        dict: Vehicle positions for each frame {frame_id: (x, y, z)}.
    """
    odom_files = sorted([f for f in os.listdir(scenario_folder) if f.startswith("odom_") and f.endswith(".txt")])
    vehicle_positions = {}

    for file in odom_files:
        frame_id = int(''.join(filter(str.isdigit, file.split('_')[1].split('.')[0])))

        with open(os.path.join(scenario_folder, file), 'r') as f:
            line = f.readline().strip()
            x, y, z, _, _, _ = map(float, line.split(','))  # Extract position
            vehicle_positions[frame_id] = (x, y, z)

    return vehicle_positions

# %%
def calculate_walking_toward_vehicle(pedestrian_positions_frames, vehicle_positions):
    """
    Calculate if pedestrians are walking toward the vehicle based on their walking direction.

    Args:
        pedestrian_positions_frames (dict): Pedestrian positions for consecutive frames.
            {frame_id: {pedestrian_id: (x, y, z)}}.
        vehicle_positions (dict): Vehicle positions for each frame {frame_id: (x, y, z)}.

    Returns:
        dict: Walking direction relative to the vehicle for each pedestrian.
            {pedestrian_id: [{"toward_vehicle": True/False, "cosine_similarity": value}, ...]}.
    """
    walking_toward_vehicle = {}

    # Get sorted frame IDs for consecutive frame comparison
    frame_ids = sorted(pedestrian_positions_frames.keys())

    for i in range(1, len(frame_ids)):  # Start from the second frame
        frame_t_minus_1 = frame_ids[i - 1]
        frame_t = frame_ids[i]

        pedestrians_t_minus_1 = pedestrian_positions_frames[frame_t_minus_1]
        pedestrians_t = pedestrian_positions_frames[frame_t]

        vehicle_pos_t = vehicle_positions.get(frame_t, (0, 0, 0))  # Default vehicle position if not provided

        for ped_id, pos_t in pedestrians_t.items():
            if ped_id in pedestrians_t_minus_1:
                pos_t_minus_1 = pedestrians_t_minus_1[ped_id]

                # Calculate pedestrian's movement vector
                movement_vector = np.array(pos_t) - np.array(pos_t_minus_1)

                # Calculate vector toward the vehicle
                toward_vehicle_vector = np.array(vehicle_pos_t) - np.array(pos_t)

                # Normalize vectors
                movement_norm = np.linalg.norm(movement_vector)
                toward_vehicle_norm = np.linalg.norm(toward_vehicle_vector)

                if movement_norm > 0 and toward_vehicle_norm > 0:
                    movement_unit = movement_vector / movement_norm
                    toward_vehicle_unit = toward_vehicle_vector / toward_vehicle_norm

                    # Compute cosine similarity
                    cosine_similarity = np.dot(movement_unit, toward_vehicle_unit)

                    # Determine if walking toward the vehicle
                    is_toward_vehicle = cosine_similarity > 0.7  # Threshold for "walking toward"
                else:
                    cosine_similarity = 0
                    is_toward_vehicle = False

                # Store results
                if ped_id not in walking_toward_vehicle:
                    walking_toward_vehicle[ped_id] = []
                walking_toward_vehicle[ped_id].append({
                    "toward_vehicle": is_toward_vehicle,
                    "cosine_similarity": cosine_similarity,
                    "movement_vector": movement_vector.tolist(),
                    "toward_vehicle_vector": toward_vehicle_vector.tolist()
                })

    return walking_toward_vehicle

# %%
# Example
scenario_folder = "/content/drive/MyDrive/Loki_Dataset/Loki/scenario_000"

pedestrian_positions_frames = load_label3d_positions(scenario_folder)
vehicle_positions = load_vehicle_positions(scenario_folder)

results = calculate_walking_toward_vehicle(pedestrian_positions_frames, vehicle_positions)

# Print results
for ped_id, movements in results.items():
    print(f"Pedestrian {ped_id}:")
    for movement in movements:
        print(f"  Toward Vehicle: {movement['toward_vehicle']}, Cosine Similarity: {movement['cosine_similarity']:.2f}")
        print(f"  Movement Vector: {movement['movement_vector']}, Toward Vehicle Vector: {movement['toward_vehicle_vector']}")
# Out:
# Pedestrian 4e34ccd4-5ed8-4155-91d4-9e812477a0fd:
#   Toward Vehicle: False, Cosine Similarity: -0.92
#   Movement Vector: [-2.583045721534763, -0.05933482337996843, -0.028598609266407005], Toward Vehicle Vector: [15.221395315089236, -5.8479215720100735, 0.9965664255447306]
# Pedestrian daab3271-6d82-4e72-84cb-064227f446e9:
#   Toward Vehicle: False, Cosine Similarity: -0.86
#   Movement Vector: [-2.6038689061590325, -0.03917475498284695, 0.012893951416426797], Toward Vehicle Vector: [10.234355545068876, -5.774212552264506, 1.0435058827582546]
#   Toward Vehicle: False, Cosine Similarity: -0.92
#   Movement Vector: [-2.6316322092948603, -0.10388966104805686, -0.020858600633070656], Toward Vehicle Vector: [15.270318961639127, -5.626550700407199, 1.1205912584414885]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-2.5330591622754994, -0.09291251935763256, 0.1200503828389351], Toward Vehicle Vector: [20.101771373426345, -5.479770632345419, 0.9928981743343573]
# Pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5:
#   Toward Vehicle: True, Cosine Similarity: 0.99
#   Movement Vector: [-1.991561791723015, -0.1251492960942162, 0.017284235747218046], Toward Vehicle Vector: [-54.55728499144553, -9.709611543432121, 1.426498882110876]
#   Toward Vehicle: True, Cosine Similarity: 0.96
#   Movement Vector: [-2.0135913442597797, -0.4979527185089818, -0.5071580036299945], Toward Vehicle Vector: [-50.188825712005084, -9.178278435709577, 2.0159956212021055]
#   Toward Vehicle: True, Cosine Similarity: 0.98
#   Movement Vector: [-1.9375358264210831, -0.03724730923203978, -0.025997957656316295], Toward Vehicle Vector: [-45.97427038485158, -9.065966854789076, 2.1300084050369725]
#   Toward Vehicle: True, Cosine Similarity: 1.00
#   Movement Vector: [-1.9505000826493557, -0.42142233381746763, 0.01209879156900806], Toward Vehicle Vector: [-41.73291489448738, -8.599655786154104, 2.1969320806043475]
#   Toward Vehicle: True, Cosine Similarity: 0.99
#   Movement Vector: [-2.0094014589838736, -0.29668596240949263, -0.03778476266847686], Toward Vehicle Vector: [-37.40408594526913, -8.246967683699445, 2.3023531841293767]
#   Toward Vehicle: True, Cosine Similarity: 0.96
#   Movement Vector: [-1.9771743850985786, -0.19068005341188865, -0.363286338753926], Toward Vehicle Vector: [-33.143967834584615, -7.966565414158254, 2.695152226302034]
#   Toward Vehicle: True, Cosine Similarity: 0.98
#   Movement Vector: [-1.9829523146467096, -0.10977820696540697, 0.11322286451716534], Toward Vehicle Vector: [-28.86356831534806, -7.807334127492377, 2.6953577160481745]
#   Toward Vehicle: True, Cosine Similarity: 0.98
#   Movement Vector: [-1.9103647062824862, -0.1985419116848206, 0.07997357219100154], Toward Vehicle Vector: [-24.728594234065575, -7.528895944578766, 2.7051470699588576]
#   Toward Vehicle: True, Cosine Similarity: 0.96
#   Movement Vector: [-1.9984097077771423, -0.13464639235980158, 0.09259491179035262], Toward Vehicle Vector: [-20.381025285565777, -7.312094264953187, 2.6906984370266898]
#   Toward Vehicle: True, Cosine Similarity: 0.86
#   Movement Vector: [-1.9862776490390388, -0.11543535112632064, 1.1200122206145906], Toward Vehicle Vector: [-16.086111924856816, -7.109461729264183, 1.625064845142873]
#   Toward Vehicle: True, Cosine Similarity: 0.89
#   Movement Vector: [-2.0407624563721427, -0.13357020093589966, 0.37589660980780026], Toward Vehicle Vector: [-11.77342258860186, -6.871422229011877, 1.266272920641622]
#   Toward Vehicle: False, Cosine Similarity: 0.67
#   Movement Vector: [-1.874550822230951, -0.06182145952745355, -0.5928768098403498], Toward Vehicle Vector: [-7.7340577710095815, -6.728395997488879, 1.9504246476076736]
#   Toward Vehicle: False, Cosine Similarity: 0.40
#   Movement Vector: [-1.9718631557797295, 0.0855367195424126, -0.034603115917137606], Toward Vehicle Vector: [-3.511919957026727, -6.776901781743816, 2.0557009908349917]
#   Toward Vehicle: False, Cosine Similarity: -0.17
#   Movement Vector: [-2.0010571626464326, 0.0677419063287843, -0.2244311331173956], Toward Vehicle Vector: [0.7275290818404088, -6.73017094122354, 2.3511670322470652]
#   Toward Vehicle: False, Cosine Similarity: -0.65
#   Movement Vector: [-1.9485794928360534, 0.07300573123537202, -0.4908224102004892], Toward Vehicle Vector: [4.935298180389353, -6.757967383861805, 2.9578325000800008]
#   Toward Vehicle: False, Cosine Similarity: -0.79
#   Movement Vector: [-1.9556664716681524, 0.26325001925404656, 0.3517845758195801], Toward Vehicle Vector: [9.141235495563365, -7.058810410203559, 2.705302293996138]
#   Toward Vehicle: False, Cosine Similarity: -0.89
#   Movement Vector: [-2.0296643139285138, 0.05323764603821601, -0.062099788425437064], Toward Vehicle Vector: [13.414861143720394, -7.004644301053787, 2.8435306844494685]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-1.9260026624997764, 0.2052064939960001, 0.14005339888077128], Toward Vehicle Vector: [17.63243637702095, -7.216645486135603, 2.794266007606966]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-1.9175889220671536, 0.07229598544986438, 0.05744128509863944], Toward Vehicle Vector: [21.739127471939668, -7.269652812489703, 2.8362258388794817]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-2.140570989795904, 0.16167745017186874, 0.3845941256873182], Toward Vehicle Vector: [26.227667516911353, -7.3475462784773065, 2.534508276264368]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-1.9570814737510744, 0.09005910756027902, 0.4508290312294039], Toward Vehicle Vector: [30.39325271380696, -7.46481264140105, 2.1058500271241973]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.0117501507323823, 0.14037923184300638, 0.0036683141718549805], Toward Vehicle Vector: [34.665767940222935, -7.610044764212379, 2.19298676666328]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.9624023473391645, 0.03702867282143529, 0.027838573708289127], Toward Vehicle Vector: [38.90504101510116, -7.6631826651679695, 2.2376626077422834]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.9555612486024785, 0.07652914981967562, -0.06507676822320896], Toward Vehicle Vector: [43.120879058137234, -7.802486711609349, 2.3922285975383684]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.9663594283577197, 0.03956050798001165, -0.059449448221036816], Toward Vehicle Vector: [47.35593813249105, -7.823693399742254, 2.5435956797697203]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.9591582193006758, 0.09344903383714076, -0.09505963661699979], Toward Vehicle Vector: [51.544290992905005, -8.018209142144153, 2.7450670118670666]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.9990127972543803, 0.038981487022629935, 0.031114113280146016], Toward Vehicle Vector: [55.827300372190635, -8.092145296258153, 2.8133634324919496]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-1.9263821899926796, 0.023813142192512515, 0.3634601459305449], Toward Vehicle Vector: [59.96094269401925, -8.117730603749127, 2.535428322419559]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8754134804441804, -0.01714878754251714, -0.10819323202118891], Toward Vehicle Vector: [63.999709140772026, -8.121648601065313, 2.710819115704786]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.914929571174767, -0.05411722390401508, 0.06638896011873952], Toward Vehicle Vector: [68.14499302102882, -8.10685637601689, 2.7261407325971554]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.9308643124432194, -0.007959485657332621, 0.1460235614782157], Toward Vehicle Vector: [72.31766336374548, -8.146408825593626, 2.664051239798749]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.9298055576533244, -0.011987437156905756, 0.09260424216142737], Toward Vehicle Vector: [76.49691960499256, -8.20003978424208, 2.634781462664177]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8689734622060286, -0.07450636353678775, 0.012115350187854479], Toward Vehicle Vector: [80.55582684405405, -8.157424766683075, 2.67049717097852]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8070258113582867, -0.012967881127618597, -0.17592956588533104], Toward Vehicle Vector: [84.56260546302953, -8.181815169552038, 3.006114017518758]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8560399594189079, -0.05285023363271435, -0.07581851755570979], Toward Vehicle Vector: [88.47785715340547, -8.169958984037915, 3.147704830072637]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.886843730827536, -0.061200794072879816, 0.12159249164873565], Toward Vehicle Vector: [92.4534688896041, -8.145391145039346, 3.190542718291455]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8044894626666377, -0.04386357943439201, -0.0036978486834917668], Toward Vehicle Vector: [96.57264035910667, -8.14248710263422, 3.143661972767183]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8193559255207958, -0.07762001308601185, -0.012118864905060978], Toward Vehicle Vector: [100.63003339400247, -8.083189080515005, 3.2618582703046903]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-1.755878924851686, -0.03279849145480895, -0.014546862472051725], Toward Vehicle Vector: [104.48416366162759, -8.114961254419693, 3.3848889241280604]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.7844105134839623, -0.0985129450251172, -0.05237808405442923], Toward Vehicle Vector: [108.41965144561937, -8.020873000594833, 3.534043732044184]
# Pedestrian 9abd7efb-f4b6-4a67-b269-188213a22d79:
#   Toward Vehicle: True, Cosine Similarity: 0.96
#   Movement Vector: [-2.572108853976694, -0.25670584644991834, -0.1940724629869574], Toward Vehicle Vector: [-27.95912582827865, -10.130129122424307, 0.636926151704288]
#   Toward Vehicle: True, Cosine Similarity: 0.94
#   Movement Vector: [-2.6293683245447355, -0.19051220521072842, -0.0562559878223835], Toward Vehicle Vector: [-22.97488956855325, -9.906236528000017, 0.7755208749879066]
#   Toward Vehicle: True, Cosine Similarity: 0.92
#   Movement Vector: [-2.4045036486621, -0.23606625792549174, -0.07812031135281938], Toward Vehicle Vector: [-18.29336641915873, -9.595105998386064, 0.9416560125192766]
#   Toward Vehicle: True, Cosine Similarity: 0.82
#   Movement Vector: [-2.8592943477257506, -0.06532669640184707, 0.10581053786588057], Toward Vehicle Vector: [-13.143216663718135, -9.484890567166712, 0.9148679417897791]
#   Toward Vehicle: False, Cosine Similarity: 0.70
#   Movement Vector: [-2.4714429847739865, -0.12236632422340321, -0.11746187980278644], Toward Vehicle Vector: [-8.352346188709774, -9.306522102898143, 1.0999661624491177]
#   Toward Vehicle: False, Cosine Similarity: 0.40
#   Movement Vector: [-2.6561994002266545, -0.1656558006874853, -0.09530191246660147], Toward Vehicle Vector: [-3.413203062897182, -9.051144086081354, 1.2247807783344509]
#   Toward Vehicle: False, Cosine Similarity: -0.12
#   Movement Vector: [-2.6547644405934534, -0.1027048379549953, 0.24593026831180098], Toward Vehicle Vector: [1.5390085822861153, -8.898986168425889, 1.0922788642859556]
#   Toward Vehicle: False, Cosine Similarity: -0.56
#   Movement Vector: [-2.5184881242649695, -0.05861771277186101, -0.0110090853896474], Toward Vehicle Vector: [6.282106081551085, -8.760472184425238, 1.1930508757772875]
#   Toward Vehicle: False, Cosine Similarity: -0.77
#   Movement Vector: [-2.67781253784743, -0.08575281989523198, 0.1630503519902049], Toward Vehicle Vector: [11.309077860121171, -8.592564077264228, 1.1081468026452674]
#   Toward Vehicle: False, Cosine Similarity: -0.85
#   Movement Vector: [-2.5204735442271584, -0.1448867065292223, 0.2848059847836213], Toward Vehicle Vector: [16.13818711601825, -8.360480186172323, 0.8777194465924201]
#   Toward Vehicle: False, Cosine Similarity: -0.91
#   Movement Vector: [-2.6704431289697297, -0.1072166530786749, 0.26808756532154704], Toward Vehicle Vector: [21.080557124870793, -8.148794233777242, 0.626736566577422]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-2.6326594805971197, -0.055087064222364646, -0.261340027114173], Toward Vehicle Vector: [25.87803060082924, -8.012502397559333, 0.979351510817297]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.422107207318689, 0.03299979752094018, -0.0015813866494227558], Toward Vehicle Vector: [30.550412466351055, -8.008471259792797, 1.0516061247769004]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.6544353083911716, -0.08582289454882464, -0.062070429120562265], Toward Vehicle Vector: [35.44323965096293, -7.8081756183949125, 1.1847114621921404]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.5420883038174154, 0.005215700581313598, -0.1291041892034246], Toward Vehicle Vector: [40.244517560493236, -7.768182030379119, 1.4296587090280113]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.7075174593395985, 0.062243291795724076, 0.07326332611174058], Toward Vehicle Vector: [45.202305863338694, -7.868018329262551, 1.4556497526519885]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.573026560767282, -0.07044973864599946, 0.047859952878039236], Toward Vehicle Vector: [50.01929375833449, -7.690164835428563, 1.4839184018018423]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.538527716606346, 0.01627947529624585, 0.07370897899148465], Toward Vehicle Vector: [54.84939404574162, -7.713239001810624, 1.5009981448486267]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.6406661736112937, -0.04383973923208018, 0.005888413133165349], Toward Vehicle Vector: [59.679162392204475, -7.65011060348278, 1.5945108480866161]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.5677301130159833, -0.060055285614108556, 0.07176157440219333], Toward Vehicle Vector: [64.59486156039624, -7.506271333684406, 1.6056258367566274]
# Pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d:
#   Toward Vehicle: True, Cosine Similarity: 0.99
#   Movement Vector: [-1.830559098815641, -0.1389115146614497, 0.08323351387966849], Toward Vehicle Vector: [-34.58638355004399, -7.831278653214174, 3.1230663196950035]
#   Toward Vehicle: True, Cosine Similarity: 0.96
#   Movement Vector: [-1.9150968312907253, -0.021553783493367007, 0.5292347255573802], Toward Vehicle Vector: [-30.32212747803061, -7.727569582455029, 2.671977872995808]
#   Toward Vehicle: True, Cosine Similarity: 0.95
#   Movement Vector: [-1.9277367009338775, -0.16352033713962477, 0.6619724041261594], Toward Vehicle Vector: [-26.08575506542681, -7.476852060752721, 2.0643840976004224]
#   Toward Vehicle: True, Cosine Similarity: 0.97
#   Movement Vector: [-2.009338723248149, -0.15074121276894736, 0.26142907692337713], Toward Vehicle Vector: [-21.804489462295848, -7.2216415486673675, 1.8200597059835946]
#   Toward Vehicle: True, Cosine Similarity: 0.83
#   Movement Vector: [-1.7814356671989202, 0.06548392541539982, -0.5295942606872484], Toward Vehicle Vector: [-17.8582397997356, -7.205920702087223, 2.440928883796545]
#   Toward Vehicle: True, Cosine Similarity: 0.78
#   Movement Vector: [-1.8847894143014159, 0.2010563861103165, -0.27643689546764905], Toward Vehicle Vector: [-13.723175727231059, -7.369946152910064, 2.7880390065743743]
#   Toward Vehicle: True, Cosine Similarity: 0.80
#   Movement Vector: [-1.842847227093685, -0.04190235783605267, 0.022885941136901122], Toward Vehicle Vector: [-9.64193662391667, -7.213571048224951, 2.836187973732151]
#   Toward Vehicle: False, Cosine Similarity: 0.45
#   Movement Vector: [-1.9545617308856649, 0.14653813276330574, -0.2700941010323956], Toward Vehicle Vector: [-5.428185287318115, -7.31489989239115, 3.222125132396993]
#   Toward Vehicle: False, Cosine Similarity: 0.08
#   Movement Vector: [-1.9256179272336311, 0.2164113242952279, 0.15484124473279182], Toward Vehicle Vector: [-1.2522965165786246, -7.568904223774085, 3.1665382573999192]
#   Toward Vehicle: False, Cosine Similarity: -0.29
#   Movement Vector: [-1.9085877111581553, 0.054292907491854336, 0.3915666100459865], Toward Vehicle Vector: [2.9002525288080463, -7.515793376077951, 2.8511002493818256]
#   Toward Vehicle: False, Cosine Similarity: -0.69
#   Movement Vector: [-1.9464607091103616, 0.22960765110069303, 0.28360383996293437], Toward Vehicle Vector: [7.138285808719189, -7.75219571826446, 2.65828513145716]
#   Toward Vehicle: False, Cosine Similarity: -0.83
#   Movement Vector: [-1.897638389442946, 0.04763919793535365, -0.1756113570673914], Toward Vehicle Vector: [11.225026371013698, -7.780546257104049, 2.9332976048957065]
#   Toward Vehicle: False, Cosine Similarity: -0.92
#   Movement Vector: [-2.0712141912235182, 0.1969245450332977, 0.03128671735503996], Toward Vehicle Vector: [15.644209617412997, -7.893686817953082, 2.984887450612871]
#   Toward Vehicle: False, Cosine Similarity: -0.85
#   Movement Vector: [-1.8942738606090046, 0.18481476144566322, 0.7408065107679278], Toward Vehicle Vector: [19.746987201166533, -8.10570883476221, 2.266251721934177]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-1.9591369481490517, 0.10726930611760643, 0.20412109892311947], Toward Vehicle Vector: [23.96688922499918, -8.217831031848139, 2.1529356767219947]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-1.8985098787554477, 0.027968251796401944, 0.18353682758240408], Toward Vehicle Vector: [28.14226983129369, -8.261908511778696, 2.041913263926883]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.8511565601807547, 0.06682819299559917, -0.1630547396885218], Toward Vehicle Vector: [32.25370318590804, -8.391511601396, 2.294457225188281]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.9424958425777987, 0.01976857886191219, -0.06396117990798245], Toward Vehicle Vector: [36.46489867448193, -8.392926360410804, 2.4503360391065785]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.8753233551770592, 0.07709076518738556, -0.3021664920728624], Toward Vehicle Vector: [40.56941667077227, -8.571083834162948, 2.8589142266597873]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-1.9306649230555877, 0.0046504990606131, 0.15618404762319327], Toward Vehicle Vector: [44.78407817585911, -8.610689000314931, 2.8021407129416236]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.00699642005344, 0.037129884848546624, 0.2971462013177144], Toward Vehicle Vector: [48.998334727748485, -8.64959105046194, 2.5905195474820633]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.8484930525537209, -0.10684100746937197, -0.012384281765460026], Toward Vehicle Vector: [53.0101807466108, -8.563816827851271, 2.6701013905115616]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.8926986345354493, -0.07676913432326593, 0.010821964598890954], Toward Vehicle Vector: [57.13323369022828, -8.526372692383596, 2.7409900029237786]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.8360022081773337, -0.038780932850285055, 0.10174080325097346], Toward Vehicle Vector: [61.21104192867905, -8.53510369476738, 2.723183268352615]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-1.8893392138219127, -0.05369704328200875, 0.23799330969256471], Toward Vehicle Vector: [65.34983182609471, -8.547025047290731, 2.5485244236869056]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8388657156433226, -0.05698795385019295, -0.17357638186883106], Toward Vehicle Vector: [69.3786313185935, -8.521928439418321, 2.7699318640579342]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8794085813879917, -0.06278298337494448, -0.09564612406428652], Toward Vehicle Vector: [73.45779270759868, -8.496503740039959, 3.0252652687771278]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-1.7229342674249182, -0.11808855463437595, 0.23257405519720065], Toward Vehicle Vector: [77.23993870598063, -8.419409233524174, 2.858463508578096]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8817141924272818, -0.0633865605287216, -0.04900118399318165], Toward Vehicle Vector: [81.21042090377901, -8.392655628069763, 3.0718950724388314]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.7308802278411406, -0.08241485588297515, -0.03961008678915867], Toward Vehicle Vector: [85.25598313845609, -8.351200309216054, 3.0609265650202264]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.7565547389251748, -0.045842170673120464, -0.13947952455186208], Toward Vehicle Vector: [89.25057498675626, -8.32368012950973, 3.306483522204535]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.7786462324059613, -0.03947393311641356, -0.02282272535615215], Toward Vehicle Vector: [93.12747256193566, -8.348776861752814, 3.4377900389120053]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.6878052207245986, -0.05977875267588573, -0.048795863776281756], Toward Vehicle Vector: [96.96635505316807, -8.293422800277185, 3.5833626265499814]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8070761408136065, -0.04818914263544727, 0.05897150686200314], Toward Vehicle Vector: [100.88899363294652, -8.269758942408888, 3.6470412661723532]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-1.7555159917676946, 0.007989144312260166, -0.013054881804481777], Toward Vehicle Vector: [104.79858524727281, -8.31493786838695, 3.7879686150178506]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8006862114700084, -0.008878878436460624, 0.15508184112012025], Toward Vehicle Vector: [108.72530142700454, -8.363767372556996, 3.721827871157252]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-1.7326323158884236, -0.013129632590292317, -0.06198549360983785], Toward Vehicle Vector: [112.58773263205312, -8.382068222831084, 3.845034487508789]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-1.8300609892352213, 0.022551035691540378, 0.02138359376079979], Toward Vehicle Vector: [116.51051365302662, -8.415847998737926, 3.939208564341251]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-1.6980127932613414, 0.011815834737513242, -0.14259716803959854], Toward Vehicle Vector: [120.1866377133778, -8.4961702531341, 4.30924108279894]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-1.6590608115113383, 0.011622486407237176, -0.048502470157143485], Toward Vehicle Vector: [123.85065763133446, -8.533121971757218, 4.548955253395537]
# Pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877:
#   Toward Vehicle: True, Cosine Similarity: 0.89
#   Movement Vector: [-2.4897821761990286, 0.1866904326142702, -0.20616449573035744], Toward Vehicle Vector: [-22.154825952381415, -7.781000777478036, 3.3183073904904687]
#   Toward Vehicle: True, Cosine Similarity: 0.84
#   Movement Vector: [-2.5377450252711498, 0.2860670887884673, 0.008841111698881132], Toward Vehicle Vector: [-17.366810083604406, -8.104660873354211, 3.4087206485273054]
#   Toward Vehicle: True, Cosine Similarity: 0.81
#   Movement Vector: [-2.523205106245456, 0.09870630996536889, 0.16783122964486097], Toward Vehicle Vector: [-12.599643643130435, -8.095963428131592, 3.3170180209103375]
#   Toward Vehicle: False, Cosine Similarity: 0.57
#   Movement Vector: [-2.5895309080244857, 0.3133603688075368, 0.13376795696534294], Toward Vehicle Vector: [-7.718540164305168, -8.416118488024944, 3.2740387859832634]
#   Toward Vehicle: False, Cosine Similarity: 0.28
#   Movement Vector: [-2.615811583713352, 0.09897488519287556, 0.07706662835148825], Toward Vehicle Vector: [-2.913626407740253, -8.495804714122055, 3.29637327400293]
#   Toward Vehicle: False, Cosine Similarity: -0.32
#   Movement Vector: [-2.5667007910894455, 0.34169721044023404, 0.05778983305569163], Toward Vehicle Vector: [2.001043438524974, -8.753717940378024, 3.321460004019443]
#   Toward Vehicle: False, Cosine Similarity: -0.55
#   Movement Vector: [-2.5155007041242925, 0.25893947519285376, 0.8812188755071688], Toward Vehicle Vector: [6.7250478657937975, -9.039864670934342, 2.4624119106015074]
#   Toward Vehicle: False, Cosine Similarity: -0.79
#   Movement Vector: [-2.573890288646922, 0.15772522243606524, 0.22466413171189248], Toward Vehicle Vector: [11.559703230124313, -9.20244278433873, 2.3285528326005527]
#   Toward Vehicle: False, Cosine Similarity: -0.87
#   Movement Vector: [-2.576498376793708, 0.06433910672229004, 0.0887494798840105], Toward Vehicle Vector: [16.413072334457084, -9.282891119195176, 2.312317767503835]
#   Toward Vehicle: False, Cosine Similarity: -0.93
#   Movement Vector: [-2.5742350619691052, 0.15257287147624332, -0.06564266799455187], Toward Vehicle Vector: [21.247584190859783, -9.498238887293123, 2.4674496570712625]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-2.5827106076312987, 0.08649866443312249, -0.05925805821412511], Toward Vehicle Vector: [26.098994444487175, -9.566383731879139, 2.6186253492957023]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.547106971794335, 0.186757553333031, -0.1588556587169363], Toward Vehicle Vector: [30.87529605739479, -9.854207993776928, 2.8838927034929855]
#   Toward Vehicle: False, Cosine Similarity: -0.96
#   Movement Vector: [-2.5792614241286316, 0.052223109501721154, 0.04313122408026859], Toward Vehicle Vector: [35.73855406355467, -9.941385770370019, 2.9401720133177465]
#   Toward Vehicle: False, Cosine Similarity: -0.96
#   Movement Vector: [-2.643677743979552, 0.16236293057349727, 0.3572780032305749], Toward Vehicle Vector: [40.58949193937016, -10.105520866241978, 2.668419045945326]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.4062648231020063, 0.028193288385946147, 0.06525353358434227], Toward Vehicle Vector: [45.15910972878076, -10.154780939486628, 2.6703630736250217]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.4850931898366326, -0.036054096947939485, 0.10504729501036847], Toward Vehicle Vector: [49.87455722769943, -10.158051841394279, 2.647026355625761]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.524562965472626, 0.06311939121641785, 0.22382536901644157], Toward Vehicle Vector: [54.64092622344549, -10.268683167844767, 2.5071350552891296]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.4524154559183273, -0.007385317871115404, 0.28703415686510525], Toward Vehicle Vector: [59.34279236295757, -10.32691624577901, 2.2834353634508795]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.400083858350044, -0.005909193303537563, -0.22003983734421617], Toward Vehicle Vector: [63.93280999816308, -10.352898398453256, 2.5513062592972933]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.4178077810479692, 0.04983118566850564, -0.1543096531485182], Toward Vehicle Vector: [68.55037058682824, -10.440087868118344, 2.8653031931007185]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.3679710434381036, 0.014374174591193167, 0.06745261165138938], Toward Vehicle Vector: [72.97755336122337, -10.495456090828128, 2.863622876447498]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.444082770410816, 0.05303170180255279, 0.23868539455896665], Toward Vehicle Vector: [77.51040413700528, -10.585120747704991, 2.789367861756085]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.3724017844804592, -0.07872720755498364, -0.1520165481426976], Toward Vehicle Vector: [82.19748792832168, -10.547353077179274, 2.890805815691019]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.3272541788515184, -0.033057346777178864, -0.06551848224899226], Toward Vehicle Vector: [86.7627792165482, -10.532617721368892, 3.0624017305724576]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.2627424229723943, 0.03805508420257908, -0.057707385895720886], Toward Vehicle Vector: [91.12377298229403, -10.635243470930968, 3.228592907819497]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.395350114270755, 0.06474803062952539, -0.03431489778885588], Toward Vehicle Vector: [95.6702003670726, -10.70441619276075, 3.359684529470047]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.2489904869458712, 0.024112291632409466, 0.009985267088473027], Toward Vehicle Vector: [100.03475329298331, -10.75305376916031, 3.472349408865949]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.369441469716122, 0.06205065996947212, 0.08737243276467366], Toward Vehicle Vector: [104.55827038525803, -10.852294210795584, 3.512849443142291]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.3930700381403938, 0.07656069445224567, 0.07405293387918155], Toward Vehicle Vector: [109.07737039166014, -10.986563287854336, 3.527737606522631]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.225186541780829, -0.018931948982062963, 0.06959765067281598], Toward Vehicle Vector: [113.43235582260112, -10.999061821736653, 3.519361078591514]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.3121958322279994, 0.022641732553418947, -0.010635410656133715], Toward Vehicle Vector: [117.8372716865674, -11.032932294505374, 3.6455541598409096]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.121673448661099, 0.05978138998530902, -0.1912011593363938], Toward Vehicle Vector: [121.93705640231835, -11.161220104149344, 4.064190669595394]
# Pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf:
#   Toward Vehicle: True, Cosine Similarity: 0.95
#   Movement Vector: [-2.2423521495395704, 0.26645712818571, 0.5500064931145099], Toward Vehicle Vector: [-19.239181865384637, -3.9715417873016072, 3.875181291348076]
#   Toward Vehicle: True, Cosine Similarity: 0.92
#   Movement Vector: [-2.2563028558766973, 0.16654583831530445, 0.10431193596072807], Toward Vehicle Vector: [-14.738917675279424, -4.030683870428923, 3.846997957415241]
#   Toward Vehicle: True, Cosine Similarity: 0.85
#   Movement Vector: [-2.3192735441218844, 0.20661522268519583, 0.11554234614750802], Toward Vehicle Vector: [-10.128071560356759, -4.244093784199935, 3.822244333306002]
#   Toward Vehicle: False, Cosine Similarity: 0.65
#   Movement Vector: [-2.1940403930172323, 0.2515609346906942, 0.1029862708519036], Toward Vehicle Vector: [-5.744928994487964, -4.476366059794865, 3.818659178825253]
#   Toward Vehicle: False, Cosine Similarity: 0.11
#   Movement Vector: [-2.3518686742155097, 0.2713109659339956, 0.12055896530704535], Toward Vehicle Vector: [-1.0450912650966728, -4.663893041544595, 3.7809767765904123]
#   Toward Vehicle: False, Cosine Similarity: -0.39
#   Movement Vector: [-2.2922113614915247, 0.1943234879401885, 0.8639334566092132], Toward Vehicle Vector: [3.455623819539383, -4.885423784848248, 2.9392141020704328]
#   Toward Vehicle: False, Cosine Similarity: -0.81
#   Movement Vector: [-2.227043821714318, 0.3387257516315465, 0.4052412302413557], Toward Vehicle Vector: [7.943432716937295, -5.229002427448117, 2.6247779255400143]
#   Toward Vehicle: False, Cosine Similarity: -0.92
#   Movement Vector: [-2.3174700713468894, 0.045814934375673744, -0.2313396843595512], Toward Vehicle Vector: [12.537773515823247, -5.290926589957946, 2.9286320246868582]
#   Toward Vehicle: False, Cosine Similarity: -0.93
#   Movement Vector: [-2.280423770643168, 0.07768803027603433, 0.2898151359353547], Toward Vehicle Vector: [17.07847408090001, -5.431389516855685, 2.7283061103243793]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.255577477157914, 0.1255102260060328, -0.29806580053694165], Toward Vehicle Vector: [21.602751204054016, -5.538545923014611, 3.1182895448716357]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.341474744077317, 0.10513616356365763, -0.3707033581721213], Toward Vehicle Vector: [26.173420589244614, -5.7447487951430265, 3.595404598524104]
#   Toward Vehicle: False, Cosine Similarity: -0.89
#   Movement Vector: [-2.1800758591258926, 0.06060364673000418, 0.8166685091757502], Toward Vehicle Vector: [30.637493030401757, -5.8403071089644, 2.878146623253383]
#   Toward Vehicle: False, Cosine Similarity: -0.96
#   Movement Vector: [-2.258827979602259, -0.01615732928672564, 0.31514720142338737], Toward Vehicle Vector: [35.10358114183995, -5.825921944976137, 2.6485244576881497]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.205980471724075, 0.1022162770981323, 0.016919464691772523], Toward Vehicle Vector: [39.47291457987262, -5.9492050069329725, 2.6988025542604155]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.2515494385171024, -0.07928002929953326, 0.09647237427400368], Toward Vehicle Vector: [43.954818327471756, -5.90924997648903, 2.68404075699752]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.2748599074867855, -0.05734237875885473, 0.29445841320729915], Toward Vehicle Vector: [48.47148426523198, -5.899419532964245, 2.4735164124700306]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.2548993001429096, -0.09176610425582066, 0.30673289998792574], Toward Vehicle Vector: [52.97583424896864, -5.873271824513783, 2.2301179775089603]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.1606037383655377, 0.08000864134863583, -0.407339779193457], Toward Vehicle Vector: [57.326371764189645, -5.985171811840202, 2.685288815204615]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.1431407166676593, -0.10077786685366519, 0.020939415676261897], Toward Vehicle Vector: [61.66926528847449, -5.921752228983119, 2.82403668018326]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.150620127698744, -0.06384561125960797, -0.007094550810640143], Toward Vehicle Vector: [65.87909714713027, -5.898900665842103, 2.896903525992069]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.0952712265246447, -0.0795430630644578, 0.0100069091547903], Toward Vehicle Vector: [70.063136379026, -5.855990557851955, 3.0513269967048324]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.294698076626659, -0.25793299454550667, -0.06323759918762883], Toward Vehicle Vector: [74.6725164624886, -5.639017100335715, 3.0639860016846976]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.163912068623574, 0.05473330656228104, 0.05445324390096351], Toward Vehicle Vector: [79.07446564048718, -5.712072397864793, 3.1156101904161804]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.056557705395676, -0.0780146654327396, -0.17115219305692975], Toward Vehicle Vector: [83.22927468865629, -5.69862839779155, 3.3952461748244285]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.071073259876343, -0.08927804746598245, 0.04220105484379921], Toward Vehicle Vector: [87.45142521904044, -5.613775041525824, 3.4498218438423236]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.129289933561992, -0.024549904582672255, -8.759658493273648e-05], Toward Vehicle Vector: [91.69627759156728, -5.613750421710303, 3.5725595869116313]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.1589671167644298, -0.040271732145767736, -0.029750254292424394], Toward Vehicle Vector: [96.0093203308903, -5.610668471230337, 3.7301823082450714]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.122293833905701, -0.027673330565674448, 0.180272790158452], Toward Vehicle Vector: [100.25764413305772, -5.640703523271169, 3.638850615346141]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.126974788709944, -0.052606948789058805, 0.0026282665708876607], Toward Vehicle Vector: [104.51441781092782, -5.61952705734649, 3.6974434715169524]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.089448362478393, -0.09206561991153173, -0.037253997405810146], Toward Vehicle Vector: [108.6965862051445, -5.53869017765026, 3.8502551395160243]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.988747545983074, -0.000792340720265905, -0.3491650337101113], Toward Vehicle Vector: [112.66344501821742, -5.606404256588655, 4.426855523644226]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.033350246697694, -0.01940034893517062, -0.17203275567342935], Toward Vehicle Vector: [116.70175437136042, -5.612333139869365, 4.790099979757109]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.064913865260536, 0.002427156081072468, 0.212436049628959], Toward Vehicle Vector: [120.90363875664049, -5.683649526440169, 4.763479741285376]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-1.9941956147165882, -0.02655937081620774, 0.03838199266811593], Toward Vehicle Vector: [124.86505849245083, -5.744472442410994, 4.9437328308621336]
# Pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283:
#   Toward Vehicle: True, Cosine Similarity: 0.76
#   Movement Vector: [-2.6882681125418486, 0.40053986732703173, 0.23346908164688918], Toward Vehicle Vector: [-11.414999155302738, -6.719142923354266, 4.1901323362036935]
#   Toward Vehicle: False, Cosine Similarity: 0.63
#   Movement Vector: [-2.50647668135079, 0.33285678795168216, 1.3067391948039895], Toward Vehicle Vector: [-6.700018750807416, -7.079206966669412, 2.9055639234889377]
#   Toward Vehicle: False, Cosine Similarity: 0.17
#   Movement Vector: [-2.553668904851918, 0.20086342905600674, 0.03860508100268434], Toward Vehicle Vector: [-1.8855847702719046, -7.284923286693742, 2.9577638961971906]
#   Toward Vehicle: False, Cosine Similarity: -0.35
#   Movement Vector: [-2.5751782336392353, 0.09774170985362574, 0.23131183896791918], Toward Vehicle Vector: [2.966464190906393, -7.398774224681523, 2.7989664720165637]
#   Toward Vehicle: False, Cosine Similarity: -0.73
#   Movement Vector: [-2.5707961777717827, 0.1867814890760151, 0.030006908165639556], Toward Vehicle Vector: [7.79753716311177, -7.648330610379242, 2.8584487854238003]
#   Toward Vehicle: False, Cosine Similarity: -0.86
#   Movement Vector: [-2.6357446107175235, 0.13863250953848016, 0.039621044502188285], Toward Vehicle Vector: [12.701981419825387, -7.768609300070615, 2.9107453749319268]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-2.613358753885535, 0.1826050152038441, -0.32275524734035765], Toward Vehicle Vector: [17.544534814824203, -8.052281023839218, 3.3399123177526313]
#   Toward Vehicle: False, Cosine Similarity: -0.91
#   Movement Vector: [-2.684263865668342, 0.055977471612767005, 0.3983668643382743], Toward Vehicle Vector: [22.512795262523795, -8.143213162543354, 3.0409559873193865]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-2.5392696446797487, 0.14746557500135538, 0.460233877188267], Toward Vehicle Vector: [27.25932503903948, -8.292450902843171, 2.6662471459892734]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-2.476135720229223, -0.03997762889275158, 0.1850310341728003], Toward Vehicle Vector: [31.8988137255773, -8.273540058809123, 2.5484136730805114]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.590842415365742, -0.08561348554412085, -0.20579994604678764], Toward Vehicle Vector: [36.72001045002507, -8.227251572120593, 2.835924196138407]
#   Toward Vehicle: False, Cosine Similarity: -0.96
#   Movement Vector: [-2.520322723106773, -0.05159051130069514, 0.3112328241600151], Toward Vehicle Vector: [41.48213920340528, -8.223172996053968, 2.608625440658202]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.526907753678472, -0.023252078616224026, 0.1164496214438343], Toward Vehicle Vector: [46.258497640677504, -8.265539313243103, 2.555510284241223]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.515546262165813, -0.0622240251920978, -0.06857539057546591], Toward Vehicle Vector: [50.963977679698786, -8.235206634028788, 2.671916733318886]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.4275998432951553, -0.0054919862348796755, -0.3176194570944386], Toward Vehicle Vector: [55.59133033061113, -8.26707293179049, 3.149223471068232]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.4858186031001424, -0.06062495254899325, 0.3350971287831732], Toward Vehicle Vector: [60.1363606646683, -8.247442027360089, 2.879898637283228]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.4447910421050523, -0.0907971463380548, 0.025300054871095323], Toward Vehicle Vector: [64.66991971214445, -8.193277836096344, 3.019028962279686]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.485768546888508, -0.15565404958266704, 0.10396772871902016], Toward Vehicle Vector: [69.4703702658689, -8.078583323542944, 2.8644826393529024]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.5042064225303875, 0.003669341873429488, -0.1434313035403476], Toward Vehicle Vector: [74.21261379777428, -8.10057465638317, 3.1139913755256963]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.3970196365636696, -0.012587734186608301, -0.16892400893173276], Toward Vehicle Vector: [78.70788477711139, -8.152557587556059, 3.3913991758087474]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.5746252811785695, -0.11872016337305702, -0.05589623026328994], Toward Vehicle Vector: [83.43358732879777, -8.038262115383258, 3.5440721299337317]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.3511226130781466, -0.037852529678975344, 0.039766051839976946], Toward Vehicle Vector: [87.90027238084076, -8.024934870471434, 3.6269562245781297]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.3930517610074133, -0.022618222719941627, 0.05558262315463791], Toward Vehicle Vector: [92.44739976440677, -8.039506429417294, 3.6992460684645074]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.5198051097904397, 0.0032653290721427197, 0.18436271166307483], Toward Vehicle Vector: [97.09323484245893, -8.100480141095943, 3.603824454060954]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.3327782360093323, -0.03337560511409343, -0.0541462467298528], Toward Vehicle Vector: [101.55581196762842, -8.09853501884623, 3.719191823532506]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.4254769407460657, -0.062096002623254876, -0.06847731779896149], Toward Vehicle Vector: [106.07400894011276, -8.047667756438276, 3.9032268119247293]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.4335609586748888, -0.03893408683169142, -0.4264772490351669], Toward Vehicle Vector: [110.4856811658775, -8.077240089265246, 4.557139411377987]
#   Toward Vehicle: False, Cosine Similarity: -1.00
#   Movement Vector: [-2.287183186681858, -0.04307686553579515, -0.1378224138536357], Toward Vehicle Vector: [114.77782345900467, -8.059492455945332, 4.886173525671076]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.5016050738303477, -0.08951328594295127, 0.24995945641214234], Toward Vehicle Vector: [119.41639905285454, -8.038868400492111, 4.82202988041616]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.3194161100912396, -0.10883363198822416, 0.022111372224131287], Toward Vehicle Vector: [123.70303928403953, -8.01741705529092, 5.018553590436902]
# Pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559:
#   Toward Vehicle: False, Cosine Similarity: -0.69
#   Movement Vector: [-2.0237798287052016, 0.23731808552286893, 0.027715780580809035], Toward Vehicle Vector: [14.991344758557787, -19.91605466924771, 1.693680562086258]
#   Toward Vehicle: False, Cosine Similarity: -0.75
#   Movement Vector: [-2.0138298119690887, 0.16608574864268633, -0.13632397386708317], Toward Vehicle Vector: [19.28204529806594, -20.098249646024552, 1.9025189507406337]
#   Toward Vehicle: False, Cosine Similarity: -0.81
#   Movement Vector: [-1.9968712206749046, 0.1834884014309388, -0.017567358324427795], Toward Vehicle Vector: [23.539193313174437, -20.344512944077195, 2.0095755306379375]
#   Toward Vehicle: False, Cosine Similarity: -0.84
#   Movement Vector: [-2.013925934025991, 0.1274770095289668, -0.04099769031908451], Toward Vehicle Vector: [27.82181889319652, -20.453636133759055, 2.142490854967337]
#   Toward Vehicle: False, Cosine Similarity: -0.88
#   Movement Vector: [-1.9971253957658917, 0.15075632232071, -0.16181193847262731], Toward Vehicle Vector: [32.048138930075694, -20.705459164644523, 2.410714488920311]
#   Toward Vehicle: False, Cosine Similarity: -0.86
#   Movement Vector: [-2.0565896382939144, -0.00484854291228487, 0.07080736081771355], Toward Vehicle Vector: [36.38872515040086, -20.735565288823608, 2.4393176620076265]
#   Toward Vehicle: False, Cosine Similarity: -0.88
#   Movement Vector: [-2.0202690481914374, 0.02607278908975985, 0.2874941829221451], Toward Vehicle Vector: [40.616254330428234, -20.76341024321183, 2.237348514943636]
#   Toward Vehicle: False, Cosine Similarity: -0.87
#   Movement Vector: [-1.913453956371157, -0.13814824638291512, 0.20270537956594037], Toward Vehicle Vector: [44.693061253107984, -20.646328781687618, 2.101840696641734]
#   Toward Vehicle: False, Cosine Similarity: -0.87
#   Movement Vector: [-1.9553219597245715, -0.2304528432889299, 0.05244217030712739], Toward Vehicle Vector: [48.87873752191459, -20.45520093725428, 2.1311091033457146]
#   Toward Vehicle: False, Cosine Similarity: -0.90
#   Movement Vector: [-2.038486840995404, -0.1638768690343433, 0.17720931609898605], Toward Vehicle Vector: [53.15903039318343, -20.338836003454006, 2.037833855926538]
#   Toward Vehicle: False, Cosine Similarity: -0.88
#   Movement Vector: [-2.0395271576972362, -0.2345604319151171, 0.3956427075662827], Toward Vehicle Vector: [57.448008234474415, -20.169893967344247, 1.7055256133871108]
#   Toward Vehicle: False, Cosine Similarity: -0.88
#   Movement Vector: [-1.9827208157255853, -0.3474290877005082, -0.1748945194709599], Toward Vehicle Vector: [61.62066282705547, -19.854356225621522, 1.928251191360268]
#   Toward Vehicle: False, Cosine Similarity: -0.90
#   Movement Vector: [-2.0715190564050374, -0.32453164244347477, -0.038283895744523955], Toward Vehicle Vector: [65.8919346910777, -19.56718286717463, 2.1262223677596994]
#   Toward Vehicle: False, Cosine Similarity: -0.92
#   Movement Vector: [-1.9623380501341785, -0.24423583293342688, -0.0010569660908446021], Toward Vehicle Vector: [69.9134844721689, -19.363941082359794, 2.1930516288487127]
#   Toward Vehicle: False, Cosine Similarity: -0.89
#   Movement Vector: [-1.9240652556614606, -0.4188300797997613, 0.040832160732004796], Toward Vehicle Vector: [73.92631773320146, -18.981743957634343, 2.3166498479842614]
#   Toward Vehicle: False, Cosine Similarity: -0.91
#   Movement Vector: [-2.212757458361864, -0.3967226247324014, 0.09035578762917185], Toward Vehicle Vector: [78.45375719839926, -18.625980869931208, 2.1757154661473264]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-2.209307616010449, -0.2388808525203423, -0.3832083473801797], Toward Vehicle Vector: [82.90110192378471, -18.405422008377663, 2.665001246159952]
#   Toward Vehicle: False, Cosine Similarity: -0.92
#   Movement Vector: [-2.0166480540277547, -0.42364568327955965, -0.07366901789880131], Toward Vehicle Vector: [87.0160013205859, -18.0463469904576, 2.847154055410072]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-2.0638217475733285, -0.33251218340159383, -0.05521062690476475], Toward Vehicle Vector: [91.23090033866704, -17.718259498256263, 2.999141406176531]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-2.1083810061117703, -0.3577313681372587, -0.06809974202085245], Toward Vehicle Vector: [95.45484378374366, -17.385053414886155, 3.1898912946817584]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-2.1654568500310063, -0.31134574095604606, 0.17606440603034867], Toward Vehicle Vector: [99.77437625633326, -17.11089745559591, 3.1416993556924253]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-2.1370236795385864, -0.3532793333920097, 0.08878656317609801], Toward Vehicle Vector: [104.03742990413356, -16.815326504810407, 3.141853889775849]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.166475312311306, -0.19439317077731388, -0.04282085753131648], Toward Vehicle Vector: [108.33370410560502, -16.652363816897473, 3.2458958700488645]
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-2.1476649955236553, -0.41837349911303434, 0.022790406288586862], Toward Vehicle Vector: [112.57408913286696, -16.24521905799974, 3.3386631343535393]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-2.0400395254376207, -0.35219358047565663, -0.30968433555262553], Toward Vehicle Vector: [116.59223992539442, -15.961531897182745, 3.8757828203242557]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.1648413152303476, -0.23795565481218262, -0.1285534440241971], Toward Vehicle Vector: [120.76204034707008, -15.748905474586444, 4.195547964787906]
#   Toward Vehicle: False, Cosine Similarity: -0.96
#   Movement Vector: [-2.1796730653821896, -0.3125483120766255, 0.13901623531381802], Toward Vehicle Vector: [125.0786839324718, -15.505246392999549, 4.2423475406313145]
# Pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09:
#   Toward Vehicle: False, Cosine Similarity: -0.94
#   Movement Vector: [-2.0117670964815346, 0.06411876864875055, 0.3715173456455987], Toward Vehicle Vector: [37.665417101764575, -9.911848338646994, 2.6838234653380795]
#   Toward Vehicle: False, Cosine Similarity: -0.96
#   Movement Vector: [-1.9449757499306486, -0.07214477435180555, -0.006519821605263099], Toward Vehicle Vector: [41.77374581800382, -9.860770349153892, 2.7575408482073804]
#   Toward Vehicle: False, Cosine Similarity: -0.96
#   Movement Vector: [-1.898312416131816, -0.12239816014464822, 0.024964963524831907], Toward Vehicle Vector: [45.902412543217665, -9.777697187864835, 2.8142864616936567]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-1.9372536891043808, -0.015789133106025588, 0.1570642957893824], Toward Vehicle Vector: [50.08147226259548, -9.809419989992879, 2.741156234584084]
#   Toward Vehicle: False, Cosine Similarity: -0.95
#   Movement Vector: [-1.9282514570332694, -0.08104214146012012, 0.3908950060907518], Toward Vehicle Vector: [54.2591744032225, -9.793996244338118, 2.413595693520188]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.8787166162931754, -0.07290372008129609, -0.191891499342555], Toward Vehicle Vector: [58.32782479637115, -9.752983870234605, 2.65331825136494]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.9585810092086433, -0.04434197610812163, -0.20962349323933527], Toward Vehicle Vector: [62.48615861319698, -9.746000178123065, 3.0226290252591825]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-1.929201458230665, -0.088135320176292, 0.24400786481271863], Toward Vehicle Vector: [66.47457180238467, -9.698858906065364, 2.844393455444633]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.8391145797530584, -0.12654543825879827, 0.013089682249991075], Toward Vehicle Vector: [70.40245438750883, -9.608946422880877, 2.9957341530621955]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.8567072740702457, -0.08575111374348054, 0.15002333892269104], Toward Vehicle Vector: [74.57384366841501, -9.564154846166662, 2.795132219931741]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.853737442789054, -0.0749121433053368, -0.19617916256195644], Toward Vehicle Vector: [78.66561822057906, -9.507564693828122, 3.0973888151261435]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.707790213480763, -0.04889555150336378, -0.17299648979651217], Toward Vehicle Vector: [82.47165977683326, -9.523239807684256, 3.378869096273974]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.999514169264316, -0.13016014813201693, 0.007824304491944378], Toward Vehicle Vector: [86.62225121660539, -9.397504350752495, 3.467821515643724]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8366533644995826, -0.05247479419131196, 0.044126637089657805], Toward Vehicle Vector: [90.57446702006982, -9.369554841328334, 3.546345025038441]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8804949393506973, -0.03188279321277854, 0.045319844775519424], Toward Vehicle Vector: [94.60903758197911, -9.374861829781358, 3.6288976473039374]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8481917473078795, -0.003123356287717982, 0.17194177659788323], Toward Vehicle Vector: [98.58325929754871, -9.429446856100146, 3.5458969679655756]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.8317404864199176, -0.021786999146797825, 0.0017494974862466428], Toward Vehicle Vector: [102.54479867312878, -9.439090339817728, 3.605368593221028]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.7831240349729711, -0.08025067143141307, 0.04892990845750589], Toward Vehicle Vector: [106.42064273984003, -9.370068408601616, 3.671996355356784]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-1.6829782615758404, -0.015204512977161855, -0.41380874514370536], Toward Vehicle Vector: [110.08173226850572, -9.423370315283115, 4.31324045091858]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.7642187617376521, -0.011516821618601014, -0.3173147516772312], Toward Vehicle Vector: [113.85091013668868, -9.437182725880396, 4.821766903035265]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.9061031922006464, 0.021925985998889175, 0.0961651707321991], Toward Vehicle Vector: [117.89398384890886, -9.527997942369016, 4.911417543460292]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-1.6456806792208312, 0.013892149975674783, 0.11239580893190926], Toward Vehicle Vector: [121.50688864922344, -9.629272379131724, 5.017656816773256]
# Pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132:
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.0622992902238764, 0.3425279292563985, -0.09916210182136176], Toward Vehicle Vector: [84.86572530712633, -32.87489092690089, 1.188219821960395]
#   Toward Vehicle: False, Cosine Similarity: -0.96
#   Movement Vector: [-2.032642744164761, 0.24733312787350314, -0.2968527944141548], Toward Vehicle Vector: [89.0494453217989, -33.12664874597465, 1.5818493402362441]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.1238472460691895, 0.3237062977105012, 0.12344146798120792], Toward Vehicle Vector: [93.28885500683293, -33.4748803284523, 1.5810580187394112]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.182023771691391, 0.3480550812539889, -0.010876840509504992], Toward Vehicle Vector: [97.62495440108292, -33.86012519137209, 1.7198073262899318]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.1474103814775845, 0.34808282080416575, 0.2731884374203104], Toward Vehicle Vector: [101.89839475082222, -34.265916394782764, 1.535559986129143]
#   Toward Vehicle: False, Cosine Similarity: -0.99
#   Movement Vector: [-2.140251014576549, 0.3248728908017853, 0.0871195519682546], Toward Vehicle Vector: [106.16844465455893, -34.62221976844893, 1.5096615569025875]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.054769584223223, 0.23711553197654922, 0.1574534434180883], Toward Vehicle Vector: [110.31593427052043, -34.87056404064078, 1.467765784077761]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-1.8901455100494502, 0.2496313987315446, -0.3449417808794468], Toward Vehicle Vector: [114.18419104765972, -35.188701859030985, 2.0401429153752986]
#   Toward Vehicle: False, Cosine Similarity: -0.97
#   Movement Vector: [-2.182455649469887, 0.12605691379462058, -0.1530313596253663], Toward Vehicle Vector: [118.37160580357492, -35.34008800504149, 2.384385975440118]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.2771420343896693, 0.4012273927870993, 0.35724847483703037], Toward Vehicle Vector: [122.78571835798412, -35.81020462831832, 2.212953311760314]
#   Toward Vehicle: False, Cosine Similarity: -0.98
#   Movement Vector: [-2.0287013927097206, 0.16570807517912556, -0.02471508222781793], Toward Vehicle Vector: [126.7816438717876, -36.063294990284476, 2.456303476233005]
