# %%
# !pip install open3d
# Out:
# Collecting open3d
#   Downloading open3d-0.18.0-cp310-cp310-manylinux_2_27_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from open3d) (1.26.4)
# Collecting dash>=2.6.0 (from open3d)
#   Downloading dash-2.18.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: werkzeug>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from open3d) (3.0.4)
# Requirement already satisfied: nbformat>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from open3d) (5.10.4)
# Collecting configargparse (from open3d)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Collecting ipywidgets>=8.0.4 (from open3d)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting addict (from open3d)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: pillow>=9.3.0 in /usr/local/lib/python3.10/dist-packages (from open3d) (10.4.0)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.10/dist-packages (from open3d) (3.7.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from open3d) (2.2.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from open3d) (6.0.2)
# Requirement already satisfied: scikit-learn>=0.21 in /usr/local/lib/python3.10/dist-packages (from open3d) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from open3d) (4.66.5)
# Collecting pyquaternion (from open3d)
#   Downloading pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (2.2.5)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (5.24.1)
# Collecting dash-html-components==2.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (4.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (2.32.3)
# Collecting retrying (from dash>=2.6.0->open3d)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (75.1.0)
# Collecting comm>=0.1.3 (from ipywidgets>=8.0.4->open3d)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.4->open3d) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.4->open3d) (5.7.1)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets>=8.0.4->open3d)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.4->open3d) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (2.8.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7.0->open3d) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7.0->open3d) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7.0->open3d) (5.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->open3d) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->open3d) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21->open3d) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21->open3d) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21->open3d) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=2.2.3->open3d) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (8.1.7)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.3.6)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (9.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.6.0->open3d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.6.0->open3d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.6.0->open3d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.6.0->open3d) (2024.8.30)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.13)
# Downloading open3d-0.18.0-cp310-cp310-manylinux_2_27_x86_64.whl (399.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.7/399.7 MB 2.7 MB/s eta 0:00:00
# Downloading dash-2.18.1-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 20.4 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 5.2 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 23.8 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.8 MB/s eta 0:00:00
# Installing collected packages: dash-table, dash-html-components, dash-core-components, addict, widgetsnbextension, retrying, pyquaternion, jedi, configargparse, comm, ipywidgets, dash, open3d
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.9
#     Uninstalling widgetsnbextension-3.6.9:
#       Successfully uninstalled widgetsnbextension-3.6.9
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed addict-2.4.0 comm-0.2.2 configargparse-1.7 dash-2.18.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 ipywidgets-8.1.5 jedi-0.19.1 open3d-0.18.0 pyquaternion-0.9.9 retrying-1.3.4 widgetsnbextension-4.0.13

# %%
# !pip install plyfile
# Out:
# Collecting plyfile
#   Downloading plyfile-1.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\legion\anaconda3\lib\site-packages (from plyfile) (1.24.4)
# Installing collected packages: plyfile
# Successfully installed plyfile-1.1
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\legion\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\legion\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\legion\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\legion\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\legion\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\legion\appdata\roaming\python\python39\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd


class PedestrianProcessor:
    """
    Processes pedestrian data, including extraction, averaging, thresholding, and filtering.
    """

    def __init__(self, points_threshold_multiplier=0.5):
        """
        Initializes the PedestrianProcessor with a threshold multiplier.

        Args:
            threshold_multiplier (float, optional): Multiplier to set the minimum point threshold based on the average
            Defaults to 0.5.
        """
        self.threshold_multiplier = points_threshold_multiplier
        self.column_names = [
            "labels", "track_id", "stationary", "pos_x", "pos_y", "pos_z",
            "dim_x", "dim_y", "dim_z", "yaw", "vehicle_state",
            "intended_actions", "potential_destination", "additional_info"
        ]
        self.numerical_columns = ["pos_x", "pos_y", "pos_z", "dim_x", "dim_y", "dim_z", "yaw"]

    def extract_pedestrian_df(self, labels3d_ndarray):
        """
        Extracts pedestrian information from the labels ndarray and returns a DataFrame.

        Args:
            labels3d_ndarray (numpy.ndarray): The labels' data.

        Returns:
            pd.DataFrame: DataFrame containing pedestrian information.

        Raises:
            SystemExit: If the labels ndarray has an unexpected shape or no pedestrians are found.
        """
        expected_num_columns = len(self.column_names)
        if labels3d_ndarray.ndim == 2 and labels3d_ndarray.shape[1] >= expected_num_columns:
            df_labels3d = pd.DataFrame(labels3d_ndarray[:, :expected_num_columns], columns=self.column_names)
        else:
            print(f"labels3d_ndarray has an unexpected shape: {labels3d_ndarray.shape}")
            exit(1)

        # Ensure numerical columns are correctly typed
        for col in self.numerical_columns:
            df_labels3d[col] = pd.to_numeric(df_labels3d[col], errors='coerce')

        # Filter to include only pedestrians
        df_pedestrians = df_labels3d[df_labels3d['labels'] == 'Pedestrian'].reset_index(drop=True)

        if df_pedestrians.empty:
            print("No pedestrian data found in this sample.")
            exit(1)

        return df_pedestrians

    @staticmethod
    def calculate_average_points(pedestrian_pcds):
        """
        Calculates the average number of points across all pedestrian point clouds.

        Args:
            pedestrian_pcds (list of o3d.geometry.PointCloud): List of pedestrian PCDs.

        Returns:
            float: The average number of points per pedestrian PCD.
        """
        total_points = sum(len(pcd_ped.points) for pcd_ped in pedestrian_pcds)
        avg_points = total_points / len(pedestrian_pcds) if pedestrian_pcds else 0
        print(f"Average number of points per pedestrian PCD: {avg_points:.2f}")
        return avg_points

    def set_min_point_threshold(self, avg_points):
        """
        Sets the minimum point threshold based on the average number of points.

        Args:
            avg_points (float): The average number of points per pedestrian PCD.

        Returns:
            float: The minimum point threshold.
        """
        min_threshold = avg_points * self.threshold_multiplier
        print(f"Minimum point threshold set to: {min_threshold:.2f}")
        return min_threshold

    @staticmethod
    def filter_pedestrians(df_pedestrians, pedestrian_pcds, min_threshold):
        """
        Filters out pedestrians with point counts below the minimum threshold.

        Args:
            df_pedestrians (pd.DataFrame): DataFrame containing pedestrian information.
            pedestrian_pcds (list of o3d.geometry.PointCloud): List of pedestrian PCDs.
            min_threshold (float): The minimum number of points required.

        Returns:
            tuple:
                pd.DataFrame: Filtered pedestrian DataFrame.
                list of o3d.geometry.PointCloud: Filtered list of pedestrian PCDs.

        Raises:
            SystemExit: If no pedestrians meet the threshold.
        """
        pedestrian_pcds_filtered = []
        df_pedestrians_filtered = pd.DataFrame(columns=df_pedestrians.columns)

        for (idx, ped_data), pcd_ped in zip(df_pedestrians.iterrows(), pedestrian_pcds):
            point_count = len(pcd_ped.points)
            if point_count >= min_threshold:
                pedestrian_pcds_filtered.append(pcd_ped)
                df_pedestrians_filtered = pd.concat([df_pedestrians_filtered, ped_data.to_frame().T], ignore_index=True)
            else:
                print(f"Removing pedestrian {ped_data['track_id']} with only {point_count} points.")

        if not pedestrian_pcds_filtered:
            print("No pedestrians meet the minimum point threshold.")
            exit(1)

        print(f"Number of pedestrians after filtering: {len(pedestrian_pcds_filtered)}")
        return df_pedestrians_filtered, pedestrian_pcds_filtered
# Out:
# C:\Users\Legion\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Legion\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\Legion\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\Legion\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
import open3d as o3d


def convert_from_vertex_to_open3d_pcd(vertex_data):
    """
    Converts vertex data to an Open3D PointCloud object.

    Args:
        vertex_data (numpy.ndarray): Array of vertex data with at least 3 columns (x, y, z).

    Returns:
        o3d.geometry.PointCloud: Converted Open3D PointCloud object.
    """
    if vertex_data.ndim != 2 or vertex_data.shape[1] < 3:
        raise ValueError("vertex_data must be a 2D NumPy array with at least 3 columns for x, y, z coordinates.")

    # Extract XYZ coordinates
    xyz = vertex_data[:, :3]

    # Initialize Open3D PointCloud
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(xyz)

    # If colors are available (assuming next three columns), assign them
    if vertex_data.shape[1] >= 6:
        colors = vertex_data[:, 3:6] / 255.0  # Normalize if colors are in [0, 255]
        pcd.colors = o3d.utility.Vector3dVector(colors)

    return pcd
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
class PointCloudProcessor:
    """
    Handles preprocessing of point clouds, including conversion, downsampling, and outlier removal.
    """

    def __init__(self, voxel_size=0.02, nb_neighbors=20, std_ratio=2.0):
        """
        Initializes the PointCloudProcessor with specified parameters.

        Args:
            voxel_size (float, optional): Voxel size for downsampling. Defaults to 0.02.
            nb_neighbors (int, optional): Number of neighbors for statistical outlier removal. Defaults to 20.
            std_ratio (float, optional): Standard deviation ratio for statistical outlier removal. Defaults to 2.0.
        """
        self.voxel_size = voxel_size
        self.nb_neighbors = nb_neighbors
        self.std_ratio = std_ratio

    def preprocess_pcd(self, raw_pcd):
        """
        Preprocesses the raw point cloud by converting, downsampling, and removing outliers.

        Args:
            raw_pcd (Any): The raw point cloud data.

        Returns:
            o3d.geometry.PointCloud: The cleaned and downsampled point cloud.

        Raises:
            SystemExit: If the point cloud cannot be converted.
        """
        # Convert pointcloud to Open3D PointCloud object
        try:
            pcd = convert_from_vertex_to_open3d_pcd(raw_pcd)
        except ValueError as ve:
            print(f"Error converting point cloud: {ve}")
            exit(1)

        print("Downsampling the point cloud...")
        pcd_down = pcd.voxel_down_sample(voxel_size=self.voxel_size)

        print("Removing statistical outliers...")
        cl, ind = pcd_down.remove_statistical_outlier(nb_neighbors=self.nb_neighbors, std_ratio=self.std_ratio)
        pcd_clean = pcd_down.select_by_index(ind)

        return pcd_clean

# %%
import numpy as np
import open3d as o3d
import pandas as pd


class BoundingBox:
    """
    Represents a bounding box in 3D space.
    """

    def __init__(self, row):
        """
        Initializes the BoundingBox object from a DataFrame row.

        Args:
            row (pd.Series): A row from the DataFrame containing bounding box info.
        """
        self.row = row
        self.obb = self.create_oriented_bounding_box()

    def create_oriented_bounding_box(self):
        """
        Creates an Oriented Bounding Box (OBB) for the pedestrian.

        Returns:
            o3d.geometry.OrientedBoundingBox or None: The oriented bounding box or None if data is invalid.
        """
        required_fields = ['pos_x', 'pos_y', 'pos_z', 'dim_x', 'dim_y', 'dim_z', 'yaw']
        for field in required_fields:
            if pd.isnull(self.row[field]):
                print(f"Missing field '{field}' in row {self.row.name}. Skipping this bounding box.")
                return None

        # Center position
        center = np.array([self.row['pos_x'], self.row['pos_y'], self.row['pos_z']])

        # Dimensions
        extent = np.array([self.row['dim_x'], self.row['dim_y'], self.row['dim_z']])

        # Yaw angle (rotation around Z-axis)
        yaw = self.row['yaw']

        # Create rotation matrix around Z-axis
        cos_yaw = np.cos(yaw)
        sin_yaw = np.sin(yaw)
        R = np.array([
            [cos_yaw, -sin_yaw, 0],
            [sin_yaw, cos_yaw, 0],
            [0, 0, 1]
        ])

        # Create the Oriented Bounding Box
        obb = o3d.geometry.OrientedBoundingBox(center, R, extent)

        return obb

# %%
class Visualizer:
    """
    Handles visualization of point clouds and bounding boxes using Open3D.
    """

    def __init__(self):
        """
        Initializes the Visualizer.
        """
        self.geometries = []
        self.bounding_boxes = []  # To store bounding box geometries
        self.pedestrian_pcds = []  # To store cropped pedestrian point clouds

    def add_point_cloud(self, pcd):
        """
        Adds a point cloud to the visualization.

        Args:
            pcd (o3d.geometry.PointCloud): The point cloud object.
        """
        self.geometries.append(pcd)

    def add_bounding_boxes(self, df_pedestrians, color=[0, 0, 1]):
        """
        Adds pedestrian bounding boxes to the visualization.

        Args:
            df_pedestrians (pd.DataFrame): DataFrame containing pedestrian bounding box information.
            color (list, optional): RGB color for the bounding boxes. Defaults to Blue ([0, 0, 1]).
        """
        for idx, row in df_pedestrians.iterrows():
            bbox_obj = BoundingBox(row)
            obb = bbox_obj.obb
            if obb is not None:
                obb.color = color
                self.geometries.append(obb)
                self.bounding_boxes.append(obb)  # Keep track of bounding boxes separately

    def clear_bounding_boxes(self):
        """
        Removes all bounding boxes from the visualization.
        """
        if not self.bounding_boxes:
            print("No bounding boxes to remove.")
            return

        for bbox in self.bounding_boxes:
            if bbox in self.geometries:
                self.geometries.remove(bbox)
        self.bounding_boxes = []  # Clear the list after removal
        print("All bounding boxes have been cleared.")

    def add_coordinate_axes(self, size=5.0, origin=[0, 0, 0]):
        """
        Adds coordinate axes to the visualization.

        Args:
            size (float, optional): Size of the coordinate frame. Defaults to 5.0.
            origin (list, optional): Origin point of the coordinate frame. Defaults to [0, 0, 0].
        """
        axes = o3d.geometry.TriangleMesh.create_coordinate_frame(size=size, origin=origin)
        self.geometries.append(axes)

    def extract_pedestrian_pcds(self, pcd, df_pedestrians):
        """
        Extracts pedestrian-specific point clouds by cropping the original point cloud
        based on the bounding boxes.

        Args:
            pcd (o3d.geometry.PointCloud): The original point cloud.
            df_pedestrians (pd.DataFrame): DataFrame containing pedestrian bounding box information.

        Returns:
            list of o3d.geometry.PointCloud: List of pedestrian-specific point clouds.
        """
        pedestrian_pcds = []
        for idx, row in df_pedestrians.iterrows():
            bbox = BoundingBox(row).obb
            if bbox is not None:
                # Use the 'crop' method of PointCloud
                cropped_pcd = pcd.crop(bbox)
                pedestrian_pcds.append(cropped_pcd)
        self.pedestrian_pcds = pedestrian_pcds
        return pedestrian_pcds

    def visualize(self, window_name='Visualization', width=1280, height=720):
        """
        Launches the Open3D visualization window with all geometries.

        Args:
            window_name (str, optional): Title of the visualization window. Defaults to 'Visualization'.
            width (int, optional): Width of the window. Defaults to 1280.
            height (int, optional): Height of the window. Defaults to 720.
        """
        o3d.visualization.draw_geometries(
            self.geometries,
            window_name=window_name,
            width=width,
            height=height,
            left=50,
            top=50,
            point_show_normal=False,
            mesh_show_wireframe=False,
            mesh_show_back_face=False
        )

    def visualize_pedestrians_only(self, window_name: object = 'Pedestrians Only', width: object = 1280, height: object = 720,
                                   color: object = [1, 0, 0]) -> object:
        """
        Visualizes only the pedestrian point clouds.

        Args:
            window_name (str, optional): Title of the visualization window. Defaults to 'Pedestrians Only'.
            width (int, optional): Width of the window. Defaults to 1280.
            height (int, optional): Height of the window. Defaults to 720.
            color (list, optional): RGB color to assign to all pedestrian point clouds. Defaults to Red ([1, 0, 0]).
        """
        pedestrian_geometries = []
        for pcd in self.pedestrian_pcds:
            # Optionally, assign a color to the pedestrian pcd
            colored_pcd = pcd.paint_uniform_color(color)
            pedestrian_geometries.append(colored_pcd)

        # Add coordinate axes
        axes = o3d.geometry.TriangleMesh.create_coordinate_frame(size=5.0, origin=[0, 0, 0])
        pedestrian_geometries.append(axes)

        # Visualize
        o3d.visualization.draw_geometries(
            pedestrian_geometries,
            window_name=window_name,
            width=width,
            height=height,
            left=50,
            top=50,
            point_show_normal=False,
            mesh_show_wireframe=False,
            mesh_show_back_face=False
        )

    def clear_geometries(self):
        """
        Clears all geometries from the visualizer.
        """
        self.geometries = []
        self.bounding_boxes = []
        self.pedestrian_pcds = []
        print("Visualizer geometries cleared.")

# %%
import os
import pandas as pd
from glob import glob
from itertools import groupby
from operator import itemgetter
import numpy as np
import threading


class PedestrianProcessingPipeline:
    """
    Encapsulates the workflow for processing and visualizing pedestrian point clouds.
    """

    def __init__(self, root_dir, csv_path, save_dir="saved_pedestrians", threshold_multiplier=0.5):
        """
        Initializes the processing pipeline.

        Args:
            root_dir (str): Root directory of the dataset.
            csv_path (str): Path to the CSV file containing pedestrian data.
            threshold_multiplier (float, optional): Multiplier for setting the minimum point threshold. Defaults to 0.5.
            save_dir (str, optional): Directory to save pedestrian point clouds. Defaults to "saved_pedestrians".
        """
        self.root_dir = root_dir
        self.csv_path = csv_path
        self.threshold_multiplier = threshold_multiplier
        self.save_dir = save_dir

        # Initialize Handlers and Processors
        self.dataset_handler = LOKIDatasetHandler(root_dir=self.root_dir, keys=["pointcloud", "labels_3d"])
        self.pointcloud_processor = PointCloudProcessor()
        self.pedestrian_processor = PedestrianProcessor(points_threshold_multiplier=self.threshold_multiplier)
        self.visualizer = Visualizer()

        # Create save directory if it doesn't exist
        if not os.path.exists(self.save_dir):
            os.makedirs(self.save_dir)
            print(f"Created directory for saving pedestrian PCDs: {self.save_dir}")

    def load_scenario_frame_ids(self):
        """
        Loads unique scenario and frame IDs from the CSV file.

        Returns:
            tuple: Tuple containing arrays of scenario_ids and frame_ids.
        """
        print(f"Retrieving scenario & frame IDs with pedestrians from file {self.csv_path}...")
        df = pd.read_csv(self.csv_path)
        target_columns = df[['video_name', 'frame_name']]

        # Extract scenario IDs by removing the 'scenario_' prefix
        scenario_ids = target_columns['video_name'].apply(lambda x: x.split('_', 1)[1]).unique()
        # Extract frame IDs by removing the 'image_' prefix
        frame_ids = target_columns['frame_name'].apply(lambda x: x.split('_', 1)[1]).unique()

        print(f"Found {len(scenario_ids)} unique scenarios and {len(frame_ids)} unique frames.")
        return scenario_ids, frame_ids

    def verify_scenarios(self, all_scenario_ids):
        """
        Verifies the existence of scenario directories.

        Args:
            all_scenario_ids (array-like): Array of scenario IDs to verify.

        Returns:
            list: List of valid scenario IDs that exist.
        """
        missing_scenarios = []
        valid_scenarios = []

        for scenario_id in all_scenario_ids:
            if self._scenario_exists(scenario_id):
                valid_scenarios.append(scenario_id)
                # print(f"Scenario {scenario_id} exists.")
            else:
                missing_scenarios.append(int(scenario_id))  # Convert to int for processing ranges
                # print(f"Scenario {scenario_id} is missing.")

        if missing_scenarios:
            missing_ranges = self._group_consecutive_ids(sorted(missing_scenarios))
            self._print_missing_scenarios(missing_ranges)
        else:
            print("All scenarios exist.")

        return valid_scenarios

    def verify_frames(self, valid_scenario_ids, all_frame_ids):
        """
        Verifies the existence of frame files within valid scenarios.

        Args:
            valid_scenario_ids (list): List of valid scenario IDs.
            all_frame_ids (list): List of all frame IDs to verify.

        Returns:
            list: List of valid frame IDs that exist across all valid scenarios.
        """
        missing_frames = {}
        valid_frame_ids = set(all_frame_ids)  # Initialize with all frames

        for scenario_id in valid_scenario_ids:
            scenario_dir = os.path.join(self.root_dir, f'scenario_{scenario_id}')
            existing_frames = self._get_existing_frames(scenario_dir, all_frame_ids)
            missing = set(all_frame_ids) - existing_frames

            if missing:
                missing_frames[scenario_id] = sorted(missing)
                valid_frame_ids &= existing_frames  # Intersection to ensure frame exists across all scenarios
                print(f"Scenario {scenario_id}: Missing frames {sorted(missing)}")
            else:
                valid_frame_ids &= existing_frames
                print(f"Scenario {scenario_id}: All frames exist.")

        if missing_frames:
            self._print_missing_frames(missing_frames)
        else:
            print("All frames exist for the valid scenarios.")

        return sorted(valid_frame_ids)

    def process_all_frames_and_crop_pedestrians(self, valid_scenario_ids, valid_frame_ids):
        """
        Processes all valid scenarios and frames, crops pedestrian point clouds,
        and saves them asynchronously.

        Args:
            valid_scenario_ids (list): List of valid scenario IDs.
            valid_frame_ids (list): List of valid frame IDs.
        """
        for scenario_id in valid_scenario_ids:
            for frame_id in valid_frame_ids:
                print(f"\nProcessing Scenario: {scenario_id}, Frame: {frame_id}")

                # Retrieve sample
                raw_pcd, labels3d_ndarray = self.get_pcd_and_labels(scenario_id, frame_id)
                if raw_pcd is None or labels3d_ndarray is None:
                    continue

                # Preprocess Point Cloud
                cleaned_pcd = self.pointcloud_processor.preprocess_pcd(raw_pcd)
                print(f"Preprocessed point cloud for Scenario: {scenario_id}, Frame: {frame_id}")

                # Extract Pedestrian DataFrame
                df_pedestrians = self.pedestrian_processor.extract_pedestrian_df(labels3d_ndarray)
                print(f"Extracted {len(df_pedestrians)} pedestrians in Scenario: {scenario_id}, Frame: {frame_id}")

                if df_pedestrians.empty:
                    print(f"No pedestrians found in Scenario: {scenario_id}, Frame: {frame_id}.")
                    continue

                # Extract Pedestrian Point Clouds
                pedestrian_pcds = self.visualizer.extract_pedestrian_pcds(cleaned_pcd, df_pedestrians)
                print(f"Extracted {len(pedestrian_pcds)} pedestrian point clouds.")

                if not pedestrian_pcds:
                    print("No pedestrian point clouds extracted.")
                    continue

                # Calculate Average Number of Points and filter low-count pedestrians
                avg_points = self.pedestrian_processor.calculate_average_points(pedestrian_pcds)

                # Set Minimum Point Threshold
                min_threshold = self.pedestrian_processor.set_min_point_threshold(avg_points)

                # Filter Pedestrians Based on Threshold
                df_pedestrians_filtered, pedestrian_pcds_filtered = self.pedestrian_processor.filter_pedestrians(
                    df_pedestrians, pedestrian_pcds, min_threshold
                )

                # Recenter and prepare pedestrian PCDs
                pedestrian_pcd_dict = self._prepare_pedestrian_pcds(
                    scenario_id, frame_id, df_pedestrians_filtered, pedestrian_pcds_filtered
                )
                print(f"Prepared pedestrian PCD dictionary for Scenario: {scenario_id}, Frame: {frame_id}")

                # Save pedestrian PCDs asynchronously
                save_thread = threading.Thread(target=self.save_pedestrian_pcds, args=(pedestrian_pcd_dict,))
                save_thread.start()
                print(f"Started saving pedestrian PCDs for Scenario: {scenario_id}, Frame: {frame_id} asynchronously.")

        print("\nProcessing completed.")

    def get_pcd_and_labels(self, scenario_id, frame_id):
        # Retrieve sample
        try:
            sample = self.dataset_handler.get_sample_by_id(scenario_id, frame_id)
            print(f"Retrieved sample for Scenario: {scenario_id}, Frame: {frame_id}")
        except Exception as e:
            print(f"Error retrieving sample for Scenario: {scenario_id}, Frame: {frame_id}: {e}")
            return None, None

        if any(not v for v in sample.values()):
            print(f"Skipping Scenario: {scenario_id}, Frame: {frame_id} as no values were found.")
            return None, None

        # Extract Point Cloud and Labels
        raw_pcd = sample.get("pointcloud", [])[0]
        labels3d_ndarray = sample.get("labels_3d", [])[0]

        return raw_pcd, labels3d_ndarray

    def save_pedestrian_pcds(self, pcd_dict):
        """
        Saves the pedestrian point clouds in the provided dictionary as .ply files asynchronously.

        Args:
            pcd_dict (dict): Dictionary where keys are a combination of scenario_id, frame_id, and pedestrian_id,
                            and values are the cropped pedestrian point clouds.
        """
        for key, pcd in pcd_dict.items():
            # Construct the filename
            filename = f"{key}.ply"
            filepath = os.path.join(self.save_dir, filename)

            # Save the point cloud to a .ply file
            try:
                o3d.io.write_point_cloud(filepath, pcd)
                print(f"Saved pedestrian PCD: {filepath}")
            except Exception as e:
                print(f"Error saving {filename}: {e}")

        print("All pedestrian point clouds for the current frame have been saved.")

    # ----------------------- Helper Methods -----------------------

    def _scenario_exists(self, scenario_id):
        """
        Checks if a scenario directory exists.

        Args:
            scenario_id (str): Scenario ID to check.

        Returns:
            bool: True if scenario exists, False otherwise.
        """
        scenario_dir = os.path.join(self.root_dir, f'scenario_{scenario_id}')
        return os.path.isdir(scenario_dir)

    @staticmethod
    def _group_consecutive_ids(id_list):
        """
        Groups consecutive IDs into ranges.

        Args:
            id_list (list): Sorted list of integer IDs.

        Returns:
            list: List of grouped ID ranges as strings.
        """
        ranges = []
        for k, g in groupby(enumerate(id_list), lambda x: x[0] - x[1]):
            group = list(map(itemgetter(1), g))
            if len(group) > 1:
                ranges.append(f"{str(group[0]).zfill(3)}-{str(group[-1]).zfill(3)}")
            else:
                ranges.append(str(group[0]).zfill(3))
        return ranges

    def _print_missing_scenarios(self, missing_ranges):
        """
        Prints the missing scenarios in grouped ranges.

        Args:
            missing_ranges (list): List of missing scenario ID ranges.
        """
        if len(missing_ranges) == 1 and '-' in missing_ranges[0]:
            print(f"Skipping the following scenarios because they do not exist in {self.root_dir}:")
            print(f"{missing_ranges[0]}")
        else:
            print(f"Skipping the following scenarios because they do not exist in {self.root_dir}:")
            print(", ".join(missing_ranges))

    @staticmethod
    def _get_existing_frames(scenario_dir, frame_ids):
        """
        Retrieves existing frame IDs within a scenario directory.

        Args:
            scenario_dir (str): Path to the scenario directory.
            frame_ids (list): List of frame IDs to check.

        Returns:
            set: Set of existing frame IDs.
        """
        existing_frames = set()
        for frame_id in frame_ids:
            # Check if any file with the pattern *_XXXX (frame_id) exists
            frame_files = glob(os.path.join(scenario_dir, f"*_{frame_id}.*"))
            if frame_files:
                existing_frames.add(frame_id)
        return existing_frames

    def _print_missing_frames(self, missing_frames):
        """
        Prints the missing frames for each scenario.

        Args:
            missing_frames (dict): Dictionary mapping scenario IDs to lists of missing frame IDs.
        """
        for scenario_id, frames in missing_frames.items():
            grouped_frames = self._group_consecutive_ids([int(f) for f in frames])
            print(f"Skipping the following frames in scenario {scenario_id} because they do not exist:")
            print(", ".join(grouped_frames))

    @staticmethod
    def _prepare_pedestrian_pcds(scenario_id, frame_id, df_pedestrians_filtered, pedestrian_pcds_filtered):
        """
        Prepares the pedestrian PCDs by recentering and creating a dictionary.

        Args:
            scenario_id (str): Scenario ID.
            frame_id (str): Frame ID.
            df_pedestrians_filtered (pd.DataFrame): Filtered pedestrian DataFrame.
            pedestrian_pcds_filtered (list): List of filtered pedestrian point clouds.

        Returns:
            dict: Dictionary with unique keys and pedestrian PCDs.
        """
        pedestrian_pcd_dict = {}
        for idx, pcd in enumerate(pedestrian_pcds_filtered):
            pedestrian_id = df_pedestrians_filtered.iloc[idx].get("Ped_ID", idx)

            # Recenter the point cloud (optional based on requirements)
            points = np.asarray(pcd.points)
            centroid = np.mean(points, axis=0)
            points_recentered = points - centroid
            pcd.points = o3d.utility.Vector3dVector(points_recentered)

            # Create a unique key for each pedestrian (scenario_id_frame_id_pedestrian_id)
            pedestrian_key = f"{scenario_id}_{frame_id}_ped_{pedestrian_id}"
            pedestrian_pcd_dict[pedestrian_key] = pcd

        return pedestrian_pcd_dict

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
import json
import torch
import plyfile
import numpy as np
import pandas as pd
from PIL import Image
from glob import glob
from torch.utils.data import Dataset


class LOKIDatasetHandler:
    """
    Handles loading and accessing samples from the LOKI dataset.
    """

    def __init__(self, root_dir, keys=["pointcloud", "labels_3d"]):
        """
        Initializes the dataset handler.

        Args:
            root_dir (str): Root directory of the LOKI dataset.
            keys (list, optional): Keys to load from the dataset. Defaults to ["pointcloud", "labels_3d"].
        """
        self.root_dir = root_dir
        self.keys = keys
        self.dataset = self._initialize_dataset()

    def _initialize_dataset(self):
        """
        Initializes the LOKIDataset.

        Returns:
            LOKIDataset: Initialized dataset object.
        """
        if not os.path.isdir(self.root_dir):
            raise ValueError(f"Provided root_dir '{self.root_dir}' is not a valid directory.")
        return LOKIDataset(root_dir=self.root_dir, keys=self.keys)

    def get_sample(self, index):
        """
        Retrieves a sample from the dataset by index.

        Args:
            index (int): Index of the sample to retrieve.

        Returns:
            dict: Sample containing pointcloud and labels_3d data.
        """
        if index < 0 or index >= len(self.dataset):
            raise IndexError(f"Sample index {index} out of range. Dataset size: {len(self.dataset)}.")
        return self.dataset[index]

    def get_sample_by_id(self, scenario_id, frame_id):
        """
        Retrieves a sample from the dataset by index.

        Args:
            scenario_id (int): ID of the scenario to retrieve frame data from.
            frame_id (int): ID of the frame to retrieve data from.

        Returns:
            dict: Sample containing pointcloud and labels_3d data.
        """
        return self.dataset.get_by_id(scenario_id, frame_id)

    def __len__(self):
        """
        Returns the number of samples in the dataset.

        Returns:
            int: Number of samples.
        """
        return len(self.dataset)


class LOKIDataset(Dataset):
    def __init__(self, root_dir, keys=None, transform=None):
        """
        Args:
            root_dir (string): Directory with all the scenarios.
            keys (list of strings): List of keys to specify which data to load.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.root_dir = root_dir
        self.keys = (
            keys
            if keys is not None
            else ["odometry", "labels_2d", "labels_3d", "pointcloud", "images", "map"]
        )
        self.transform = transform
        self.scenarios = [
            os.path.join(root_dir, scenario) for scenario in os.listdir(root_dir)
        ]

    def __len__(self):
        return len(self.scenarios)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        scenario_path = self.scenarios[idx]
        sample = {}

        if "odometry" in self.keys:
            sample["odometry"] = self.load_odometry(scenario_path)
        if "labels_2d" in self.keys:
            sample["labels_2d"] = self.load_labels_2d(scenario_path)
        if "labels_3d" in self.keys:
            sample["labels_3d"] = self.load_labels_3d(scenario_path)
        if "pointcloud" in self.keys:
            sample["pointcloud"] = self.load_pointcloud(scenario_path)
        if "images" in self.keys:
            sample["images"] = self.load_images(scenario_path)
        if "map" in self.keys:
            sample["map"] = self.load_map(scenario_path)

        if self.transform and "images" in sample:
            sample["images"] = [self.transform(image) for image in sample["images"]]

        return sample

    def get_by_id(self, scenario_id, frame_id):
        if torch.is_tensor(scenario_id):
            scenario_id = scenario_id.tolist()

        if torch.is_tensor(frame_id):
            frame_id = frame_id.tolist()

        matching_scenario_paths = [
            scenario_path for scenario_path in self.scenarios
            if f'scenario_{scenario_id}' in os.path.basename(scenario_path)
        ]

        scenario_path = matching_scenario_paths[0]

        sample = {}

        if "odometry" in self.keys:
            sample["odometry"] = self.load_odometry(scenario_path, frame_id)
        if "labels_2d" in self.keys:
            sample["labels_2d"] = self.load_labels_2d(scenario_path, frame_id)
        if "labels_3d" in self.keys:
            sample["labels_3d"] = self.load_labels_3d(scenario_path, frame_id)
        if "pointcloud" in self.keys:
            sample["pointcloud"] = self.load_pointcloud(scenario_path, frame_id)
        if "images" in self.keys:
            sample["images"] = self.load_images(scenario_path, frame_id)
        if "map" in self.keys:
            sample["map"] = self.load_map(scenario_path)

        if self.transform and "images" in sample:
            sample["images"] = [self.transform(image) for image in sample["images"]]

        return sample

    @staticmethod
    def load_odometry(scenario_path, frame_id=None):
        # Get all odom files or filter for a specific frame if frame_id is provided
        if frame_id:
            # If frame_id is provided, look for a specific odometry file like 'odom_0024.txt'
            odometry_files = glob(os.path.join(scenario_path, f"odom_{frame_id}.txt"))
        else:
            # Otherwise, load all odometry files
            odometry_files = sorted(glob(os.path.join(scenario_path, "odom_*.txt")))

        # Load odometry data from the selected files
        odometry_data = [
            pd.read_csv(f, header=None, dtype=float).values for f in odometry_files
        ]

        return odometry_data

    @staticmethod
    def load_labels_2d(scenario_path, frame_id=None):
        # Get all label2d files or filter for a specific frame if frame_id is provided
        if frame_id:
            label2d_files = glob(os.path.join(scenario_path, f"label2d_{frame_id}.json"))
        else:
            label2d_files = sorted(glob(os.path.join(scenario_path, "label2d_*.json")))

        # Load label 2d data from the selected files
        labels_2d = [json.load(open(f)) for f in label2d_files]
        return labels_2d

    @staticmethod
    def load_labels_3d(scenario_path, frame_id=None):
        # Get all label3d files or filter for a specific frame if frame_id is provided
        if frame_id:
            label3d_files = glob(os.path.join(scenario_path, f"label3d_{frame_id}.txt"))
        else:
            label3d_files = sorted(glob(os.path.join(scenario_path, "label3d_*.txt")))

        # Load label 3d data from the selected files
        labels_3d = [pd.read_csv(f).values for f in label3d_files]
        return labels_3d

    def load_pointcloud(self, scenario_path, frame_id=None):
        # Get all pointcloud files or filter for a specific frame if frame_id is provided
        if frame_id:
            pointcloud_files = glob(os.path.join(scenario_path, f"pc_{frame_id}.ply"))
        else:
            pointcloud_files = sorted(glob(os.path.join(scenario_path, "pc_*.ply")))

        # Load pointcloud data from the selected files
        pointcloud_data = [self.load_ply(f) for f in pointcloud_files]
        return pointcloud_data

    @staticmethod
    def load_images(scenario_path, frame_id=None):
        # Get all image files or filter for a specific frame if frame_id is provided
        if frame_id:
            image_files = glob(os.path.join(scenario_path, f"image_{frame_id}.png"))
        else:
            image_files = sorted(glob(os.path.join(scenario_path, "image_*.png")))

        # Load images from the selected files
        images = [Image.open(f).convert("RGB") for f in image_files]
        return images

    def load_map(self, scenario_path):
        map_file = os.path.join(scenario_path, "map.ply")
        map_data = self.load_ply(map_file)
        return map_data

    def load_ply(self, file_path):
        plydata = plyfile.PlyData.read(file_path)
        return np.array([list(vertex) for vertex in plydata.elements[0]])

# Example usage of the custom dataset and dataloader
# root_dir = "../Datasets/loki_data/"
# keys = ["odometry", "images"]
# loki_dataset = LOKIDataset(root_dir=root_dir, keys=keys, transform=None)
# sample = loki_dataset.__getitem__(0)
# print("Loaded Successfully")

# %%
# Define the paths directly
root_dir = '../LOKI'
csv_path = 'loki.csv'
threshold_multiplier = 0.5
output_csv = '../LOKI/pedestrian_pointclouds.csv'

# Create the pipeline instance
pipeline = PedestrianProcessingPipeline(
    root_dir=root_dir,
    csv_path=csv_path,
    threshold_multiplier=threshold_multiplier
)

try:

  # Load scenario and frame IDs
  scenario_ids, frame_ids = pipeline.load_scenario_frame_ids()

  # Verify scenarios
  valid_scenario_ids = pipeline.verify_scenarios(scenario_ids)

  # Verify frames
  valid_frame_ids = pipeline.verify_frames(valid_scenario_ids, frame_ids)

  # Process all valid frames & save pcds
  pipeline.process_all_frames_and_crop_pedestrians(valid_scenario_ids, valid_frame_ids)

except KeyboardInterrupt:
  print("\nOperation cancelled by user. Exiting gracefully...")
# Out:
# Created directory for saving pedestrian PCDs: saved_pedestrians
# Retrieving scenario & frame IDs with pedestrians from file loki.csv...
# Found 604 unique scenarios and 102 unique frames.
# Skipping the following scenarios because they do not exist in ../LOKI:
# 001-014, 016-019, 021-025, 027-041, 043-086, 088-089, 091-093, 095-100, 104-109, 111-115, 117-174, 176-181, 184-200, 202-221, 225-233, 235-265, 267-291, 293-316, 318-323, 325-346, 348-349, 351-373, 376-404, 406-415, 418-489, 491-524, 526, 528, 531-532, 536-556, 558-633, 635-643
# Scenario 000: Missing frames ['0104', '0106', '0108', '0110', '0112', '0114', '0116', '0118', '0120', '0122', '0124', '0126', '0128', '0130', '0132', '0134', '0136', '0138', '0140', '0142', '0144', '0146', '0148', '0150', '0152', '0154', '0156', '0158', '0160', '0162', '0164', '0166', '0168', '0170', '0172', '0174', '0176', '0178', '0180', '0182', '0184', '0186', '0188', '0190', '0192', '0194', '0196', '0198', '0200', '0202']
# Scenario 026: Missing frames ['0200', '0202']
# Skipping the following frames in scenario 000 because they do not exist:
# 104, 106, 108, 110, 112, 114, 116, 118, 120, 122, 124, 126, 128, 130, 132, 134, 136, 138, 140, 142, 144, 146, 148, 150, 152, 154, 156, 158, 160, 162, 164, 166, 168, 170, 172, 174, 176, 178, 180, 182, 184, 186, 188, 190, 192, 194, 196, 198, 200, 202
# Skipping the following frames in scenario 026 because they do not exist:
# 200, 202
#
# Processing Scenario: 000, Frame: 0000
# Retrieved sample for Scenario: 000, Frame: 0000
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0000
# Extracted 2 pedestrians in Scenario: 000, Frame: 0000
# Extracted 2 pedestrian point clouds.
# Average number of points per pedestrian PCD: 45.50
# Minimum point threshold set to: 22.75
# Removing pedestrian daab3271-6d82-4e72-84cb-064227f446e9 with only 22 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0000
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0000 asynchronously.
#
# Processing Scenario: 000, Frame: 0002
# Saved pedestrian PCD: saved_pedestrians\000_0000_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0002
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0002
# Extracted 2 pedestrians in Scenario: 000, Frame: 0002
# Extracted 2 pedestrian point clouds.
# Average number of points per pedestrian PCD: 70.50
# Minimum point threshold set to: 35.25
# Removing pedestrian daab3271-6d82-4e72-84cb-064227f446e9 with only 29 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0002
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0002 asynchronously.Saved pedestrian PCD: saved_pedestrians\000_0002_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
#
#
# Processing Scenario: 000, Frame: 0004
# Retrieved sample for Scenario: 000, Frame: 0004
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0004
# Extracted 3 pedestrians in Scenario: 000, Frame: 0004
# Extracted 3 pedestrian point clouds.
# Average number of points per pedestrian PCD: 13.00
# Minimum point threshold set to: 6.50
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 0 points.
# Number of pedestrians after filtering: 2
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0004
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0004 asynchronously.
#
# Processing Scenario: 000, Frame: 0006
# Saved pedestrian PCD: saved_pedestrians\000_0004_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0004_ped_1.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0006
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0006
# Extracted 3 pedestrians in Scenario: 000, Frame: 0006
# Extracted 3 pedestrian point clouds.
# Average number of points per pedestrian PCD: 21.67
# Minimum point threshold set to: 10.83
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 0 points.
# Number of pedestrians after filtering: 2
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0006
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0006 asynchronously.
#
# Processing Scenario: 000, Frame: 0008
# Saved pedestrian PCD: saved_pedestrians\000_0006_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0006_ped_1.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0008
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0008
# Extracted 2 pedestrians in Scenario: 000, Frame: 0008
# Extracted 2 pedestrian point clouds.
# Average number of points per pedestrian PCD: 11.00
# Minimum point threshold set to: 5.50
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 0 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0008
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0008 asynchronously.
#
# Processing Scenario: 000, Frame: 0010
# Saved pedestrian PCD: saved_pedestrians\000_0008_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0010
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0010
# Extracted 2 pedestrians in Scenario: 000, Frame: 0010
# Extracted 2 pedestrian point clouds.
# Average number of points per pedestrian PCD: 10.00
# Minimum point threshold set to: 5.00
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 0 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0010
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0010 asynchronously.
#
# Processing Scenario: 000, Frame: 0012
# Saved pedestrian PCD: saved_pedestrians\000_0010_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0012
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0012
# Extracted 2 pedestrians in Scenario: 000, Frame: 0012
# Extracted 2 pedestrian point clouds.
# Average number of points per pedestrian PCD: 10.00
# Minimum point threshold set to: 5.00
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 0 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0012
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0012 asynchronously.
#
# Processing Scenario: 000, Frame: 0014
# Saved pedestrian PCD: saved_pedestrians\000_0012_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0014
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0014
# Extracted 2 pedestrians in Scenario: 000, Frame: 0014
# Extracted 2 pedestrian point clouds.
# Average number of points per pedestrian PCD: 13.50
# Minimum point threshold set to: 6.75
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 0 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0014
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0014 asynchronously.
#
# Processing Scenario: 000, Frame: 0016
# Saved pedestrian PCD: saved_pedestrians\000_0014_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0016
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0016
# Extracted 2 pedestrians in Scenario: 000, Frame: 0016
# Extracted 2 pedestrian point clouds.
# Average number of points per pedestrian PCD: 13.00
# Minimum point threshold set to: 6.50
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 0 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0016
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0016 asynchronously.
#
# Processing Scenario: 000, Frame: 0018
# Saved pedestrian PCD: saved_pedestrians\000_0016_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0018
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0018
# Extracted 3 pedestrians in Scenario: 000, Frame: 0018
# Extracted 3 pedestrian point clouds.
# Average number of points per pedestrian PCD: 10.33
# Minimum point threshold set to: 5.17
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 5 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 0 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0018
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0018 asynchronously.
#
# Processing Scenario: 000, Frame: 0020
# Saved pedestrian PCD: saved_pedestrians\000_0018_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0020
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0020
# Extracted 3 pedestrians in Scenario: 000, Frame: 0020
# Extracted 3 pedestrian point clouds.
# Average number of points per pedestrian PCD: 11.00
# Minimum point threshold set to: 5.50
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 5 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 0 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0020
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0020 asynchronously.
#
# Processing Scenario: 000, Frame: 0022
# Saved pedestrian PCD: saved_pedestrians\000_0020_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0022
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0022
# Extracted 3 pedestrians in Scenario: 000, Frame: 0022
# Extracted 3 pedestrian point clouds.
# Average number of points per pedestrian PCD: 17.67
# Minimum point threshold set to: 8.83
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 5 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 2 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0022
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0022 asynchronously.
#
# Processing Scenario: 000, Frame: 0024
# Saved pedestrian PCD: saved_pedestrians\000_0022_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0024
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0024
# Extracted 3 pedestrians in Scenario: 000, Frame: 0024
# Extracted 3 pedestrian point clouds.
# Average number of points per pedestrian PCD: 16.33
# Minimum point threshold set to: 8.17
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 5 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 2 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0024
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0024 asynchronously.
#
# Processing Scenario: 000, Frame: 0026
# Saved pedestrian PCD: saved_pedestrians\000_0024_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0026
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0026
# Extracted 3 pedestrians in Scenario: 000, Frame: 0026
# Extracted 3 pedestrian point clouds.
# Average number of points per pedestrian PCD: 22.00
# Minimum point threshold set to: 11.00
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 5 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 9 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0026
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0026 asynchronously.
#
# Processing Scenario: 000, Frame: 0028
# Saved pedestrian PCD: saved_pedestrians\000_0026_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0028
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0028
# Extracted 3 pedestrians in Scenario: 000, Frame: 0028
# Extracted 3 pedestrian point clouds.
# Average number of points per pedestrian PCD: 36.00
# Minimum point threshold set to: 18.00
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 11 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 12 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0028
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0028 asynchronously.Saved pedestrian PCD: saved_pedestrians\000_0028_ped_0.ply
#
# All pedestrian point clouds for the current frame have been saved.
#
# Processing Scenario: 000, Frame: 0030
# Retrieved sample for Scenario: 000, Frame: 0030
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0030
# Extracted 3 pedestrians in Scenario: 000, Frame: 0030
# Extracted 3 pedestrian point clouds.
# Average number of points per pedestrian PCD: 42.33
# Minimum point threshold set to: 21.17
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 0 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 11 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0030
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0030 asynchronously.
#
# Processing Scenario: 000, Frame: 0032
# Saved pedestrian PCD: saved_pedestrians\000_0030_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0032
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0032
# Extracted 4 pedestrians in Scenario: 000, Frame: 0032
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 39.00
# Minimum point threshold set to: 19.50
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 0 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 15 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 4 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0032
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0032 asynchronously.
#
# Processing Scenario: 000, Frame: 0034
# Saved pedestrian PCD: saved_pedestrians\000_0032_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0034
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0034
# Extracted 5 pedestrians in Scenario: 000, Frame: 0034
# Extracted 5 pedestrian point clouds.
# Average number of points per pedestrian PCD: 40.00
# Minimum point threshold set to: 20.00
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 0 points.
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 6 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 15 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 5 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0034
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0034 asynchronously.
#
# Processing Scenario: 000, Frame: 0036
# Saved pedestrian PCD: saved_pedestrians\000_0034_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0036
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0036
# Extracted 5 pedestrians in Scenario: 000, Frame: 0036
# Extracted 5 pedestrian point clouds.
# Average number of points per pedestrian PCD: 50.60
# Minimum point threshold set to: 25.30
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 0 points.
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 7 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 21 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 3 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0036
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0036 asynchronously.
#
# Processing Scenario: 000, Frame: 0038
# Saved pedestrian PCD: saved_pedestrians\000_0036_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0038
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0038
# Extracted 5 pedestrians in Scenario: 000, Frame: 0038
# Extracted 5 pedestrian point clouds.
# Average number of points per pedestrian PCD: 54.40
# Minimum point threshold set to: 27.20
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 0 points.
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 6 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 20 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 5 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0038
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0038 asynchronously.
#
# Processing Scenario: 000, Frame: 0040
# Saved pedestrian PCD: saved_pedestrians\000_0038_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0040
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0040
# Extracted 5 pedestrians in Scenario: 000, Frame: 0040
# Extracted 5 pedestrian point clouds.
# Average number of points per pedestrian PCD: 60.80
# Minimum point threshold set to: 30.40
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 0 points.
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 4 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 22 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 7 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0040
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0040 asynchronously.
#
# Processing Scenario: 000, Frame: 0042
# Saved pedestrian PCD: saved_pedestrians\000_0040_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0042
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0042
# Extracted 6 pedestrians in Scenario: 000, Frame: 0042
# Extracted 6 pedestrian point clouds.
# Average number of points per pedestrian PCD: 66.17
# Minimum point threshold set to: 33.08
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 5 points.
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 6 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 17 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 3 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 5 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0042
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0042 asynchronously.
#
# Processing Scenario: 000, Frame: 0044
# Saved pedestrian PCD: saved_pedestrians\000_0042_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0044
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0044
# Extracted 6 pedestrians in Scenario: 000, Frame: 0044
# Extracted 6 pedestrian point clouds.
# Average number of points per pedestrian PCD: 74.83
# Minimum point threshold set to: 37.42
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 12 points.
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 6 points.
# Removing pedestrian 8f62a01b-8bfe-4bde-87f7-52bb205d4cb5 with only 22 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 7 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 5 points.
# Number of pedestrians after filtering: 1
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0044
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0044 asynchronously.
#
# Processing Scenario: 000, Frame: 0046
# Saved pedestrian PCD: saved_pedestrians\000_0044_ped_0.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0046
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0046
# Extracted 6 pedestrians in Scenario: 000, Frame: 0046
# Extracted 6 pedestrian point clouds.
# Average number of points per pedestrian PCD: 10.17
# Minimum point threshold set to: 5.08
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 4 points.
# Number of pedestrians after filtering: 5
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0046
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0046 asynchronously.Saved pedestrian PCD: saved_pedestrians\000_0046_ped_0.ply
#
#
# Processing Scenario: 000, Frame: 0048
# Saved pedestrian PCD: saved_pedestrians\000_0046_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0046_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0046_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0046_ped_4.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0048
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0048
# Extracted 6 pedestrians in Scenario: 000, Frame: 0048
# Extracted 6 pedestrian point clouds.
# Average number of points per pedestrian PCD: 10.17
# Minimum point threshold set to: 5.08
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 3 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 3 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 5 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0048
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0048 asynchronously.
#
# Processing Scenario: 000, Frame: 0050
# Saved pedestrian PCD: saved_pedestrians\000_0048_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0048_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0048_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0050
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0050
# Extracted 6 pedestrians in Scenario: 000, Frame: 0050
# Extracted 6 pedestrian point clouds.
# Average number of points per pedestrian PCD: 12.00
# Minimum point threshold set to: 6.00
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 5 points.
# Number of pedestrians after filtering: 5
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0050
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0050 asynchronously.
#
# Processing Scenario: 000, Frame: 0052
# Saved pedestrian PCD: saved_pedestrians\000_0050_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0050_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0050_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0050_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0050_ped_4.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0052
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0052
# Extracted 6 pedestrians in Scenario: 000, Frame: 0052
# Extracted 6 pedestrian point clouds.
# Average number of points per pedestrian PCD: 12.00
# Minimum point threshold set to: 6.00
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 4 points.
# Number of pedestrians after filtering: 5
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0052
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0052 asynchronously.
#
# Processing Scenario: 000, Frame: 0054
# Saved pedestrian PCD: saved_pedestrians\000_0052_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0052_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0052_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0052_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0052_ped_4.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0054
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0054
# Extracted 6 pedestrians in Scenario: 000, Frame: 0054
# Extracted 6 pedestrian point clouds.
# Average number of points per pedestrian PCD: 16.17
# Minimum point threshold set to: 8.08
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 2 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 8 points.
# Number of pedestrians after filtering: 4
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0054
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0054 asynchronously.
#
# Processing Scenario: 000, Frame: 0056
# Saved pedestrian PCD: saved_pedestrians\000_0054_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0054_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0054_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0054_ped_3.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0056
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0056
# Extracted 6 pedestrians in Scenario: 000, Frame: 0056
# Extracted 6 pedestrian point clouds.
# Average number of points per pedestrian PCD: 17.83
# Minimum point threshold set to: 8.92
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 2 points.
# Number of pedestrians after filtering: 5
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0056
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0056 asynchronously.
#
# Processing Scenario: 000, Frame: 0058
# Saved pedestrian PCD: saved_pedestrians\000_0056_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0056_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0056_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0056_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0056_ped_4.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0058
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0058
# Extracted 7 pedestrians in Scenario: 000, Frame: 0058
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 16.71
# Minimum point threshold set to: 8.36
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 8 points.
# Removing pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09 with only 6 points.
# Number of pedestrians after filtering: 5
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0058
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0058 asynchronously.
#
# Processing Scenario: 000, Frame: 0060
# Saved pedestrian PCD: saved_pedestrians\000_0058_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0058_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0058_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0058_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0058_ped_4.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0060
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0060
# Extracted 7 pedestrians in Scenario: 000, Frame: 0060
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 18.71
# Minimum point threshold set to: 9.36
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 9 points.
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 6 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 9 points.
# Number of pedestrians after filtering: 4
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0060
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0060 asynchronously.
#
# Processing Scenario: 000, Frame: 0062
# Saved pedestrian PCD: saved_pedestrians\000_0060_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0060_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0060_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0060_ped_3.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0062
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0062
# Extracted 7 pedestrians in Scenario: 000, Frame: 0062
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 22.29
# Minimum point threshold set to: 11.14
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 4 points.
# Removing pedestrian 4ab64275-275c-4f58-8ed5-39837a4a265d with only 9 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 11 points.
# Removing pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09 with only 10 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0062
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0062 asynchronously.
#
# Processing Scenario: 000, Frame: 0064
# Saved pedestrian PCD: saved_pedestrians\000_0062_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0062_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0062_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0064
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0064
# Extracted 7 pedestrians in Scenario: 000, Frame: 0064
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 26.71
# Minimum point threshold set to: 13.36
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 0 points.
# Number of pedestrians after filtering: 6
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0064
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0064 asynchronously.
#
# Processing Scenario: 000, Frame: 0066
# Saved pedestrian PCD: saved_pedestrians\000_0064_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0064_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0064_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0064_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0064_ped_4.ply
# Saved pedestrian PCD: saved_pedestrians\000_0064_ped_5.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0066
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0066
# Extracted 7 pedestrians in Scenario: 000, Frame: 0066
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 34.29
# Minimum point threshold set to: 17.14
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 0 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 12 points.
# Removing pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09 with only 14 points.
# Number of pedestrians after filtering: 4
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0066
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0066 asynchronously.
#
# Processing Scenario: 000, Frame: 0068
# Saved pedestrian PCD: saved_pedestrians\000_0066_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0066_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0066_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0066_ped_3.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0068
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0068
# Extracted 7 pedestrians in Scenario: 000, Frame: 0068
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 34.00
# Minimum point threshold set to: 17.00
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 5 points.
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 16 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 16 points.
# Removing pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09 with only 10 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0068
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0068 asynchronously.
#
# Processing Scenario: 000, Frame: 0070
# Saved pedestrian PCD: saved_pedestrians\000_0068_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0068_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0068_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0070
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0070
# Extracted 7 pedestrians in Scenario: 000, Frame: 0070
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 40.86
# Minimum point threshold set to: 20.43
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 7 points.
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 19 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 18 points.
# Removing pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09 with only 18 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0070
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0070 asynchronously.
#
# Processing Scenario: 000, Frame: 0072
# Saved pedestrian PCD: saved_pedestrians\000_0070_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0070_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0070_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0072
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0072
# Extracted 7 pedestrians in Scenario: 000, Frame: 0072
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 43.14
# Minimum point threshold set to: 21.57
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 3 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 13 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 18 points.
# Number of pedestrians after filtering: 4
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0072
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0072 asynchronously.
#
# Processing Scenario: 000, Frame: 0074
# Saved pedestrian PCD: saved_pedestrians\000_0072_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0072_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0072_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0072_ped_3.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0074
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0074
# Extracted 7 pedestrians in Scenario: 000, Frame: 0074
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 37.00
# Minimum point threshold set to: 18.50
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 3 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 17 points.
# Number of pedestrians after filtering: 5
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0074
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0074 asynchronously.
#
# Processing Scenario: 000, Frame: 0076
# Saved pedestrian PCD: saved_pedestrians\000_0074_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0074_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0074_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0074_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0074_ped_4.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0076
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0076
# Extracted 7 pedestrians in Scenario: 000, Frame: 0076
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 59.86
# Minimum point threshold set to: 29.93
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 5 points.
# Removing pedestrian a10e71cd-07bd-47c6-9d73-3bdd248fb877 with only 20 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 27 points.
# Number of pedestrians after filtering: 4
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0076
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0076 asynchronously.
#
# Processing Scenario: 000, Frame: 0078
# Saved pedestrian PCD: saved_pedestrians\000_0076_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0076_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0076_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0076_ped_3.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0078
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0078
# Extracted 7 pedestrians in Scenario: 000, Frame: 0078
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 74.71
# Minimum point threshold set to: 37.36
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 8 points.
# Removing pedestrian 839d38a7-7b2a-459e-a680-bcb383bb7fcf with only 33 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 34 points.
# Removing pedestrian ec49b5eb-b6d3-4bd8-8fd1-1ec1ce9e6f09 with only 27 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0078
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0078 asynchronously.
#
# Processing Scenario: 000, Frame: 0080
# Saved pedestrian PCD: saved_pedestrians\000_0078_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0078_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0078_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0080
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0080
# Extracted 8 pedestrians in Scenario: 000, Frame: 0080
# Extracted 8 pedestrian point clouds.
# Average number of points per pedestrian PCD: 75.50
# Minimum point threshold set to: 37.75
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 5 points.
# Removing pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132 with only 0 points.
# Number of pedestrians after filtering: 6
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0080
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0080 asynchronously.
#
# Processing Scenario: 000, Frame: 0082
# Saved pedestrian PCD: saved_pedestrians\000_0080_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0080_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0080_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0080_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0080_ped_4.ply
# Saved pedestrian PCD: saved_pedestrians\000_0080_ped_5.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0082
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0082
# Extracted 8 pedestrians in Scenario: 000, Frame: 0082
# Extracted 8 pedestrian point clouds.
# Average number of points per pedestrian PCD: 90.88
# Minimum point threshold set to: 45.44
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 13 points.
# Removing pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132 with only 1 points.
# Number of pedestrians after filtering: 6
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0082
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0082 asynchronously.
#
# Processing Scenario: 000, Frame: 0084
# Saved pedestrian PCD: saved_pedestrians\000_0082_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0082_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0082_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0082_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0082_ped_4.ply
# Saved pedestrian PCD: saved_pedestrians\000_0082_ped_5.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0084
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0084
# Extracted 8 pedestrians in Scenario: 000, Frame: 0084
# Extracted 8 pedestrian point clouds.
# Average number of points per pedestrian PCD: 116.12
# Minimum point threshold set to: 58.06
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 31 points.
# Removing pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132 with only 1 points.
# Removing pedestrian db09f2ef-f3c8-40e2-86aa-231c624b4283 with only 52 points.
# Number of pedestrians after filtering: 5
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0084
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0084 asynchronously.
#
# Processing Scenario: 000, Frame: 0086
# Saved pedestrian PCD: saved_pedestrians\000_0084_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0084_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0084_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0084_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0084_ped_4.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0086
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0086
# Extracted 7 pedestrians in Scenario: 000, Frame: 0086
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 104.29
# Minimum point threshold set to: 52.14
# Removing pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132 with only 0 points.
# Number of pedestrians after filtering: 6
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0086
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0086 asynchronously.
#
# Processing Scenario: 000, Frame: 0088
# Saved pedestrian PCD: saved_pedestrians\000_0086_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0086_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0086_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0086_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0086_ped_4.ply
# Saved pedestrian PCD: saved_pedestrians\000_0086_ped_5.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0088
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0088
# Extracted 7 pedestrians in Scenario: 000, Frame: 0088
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 118.71
# Minimum point threshold set to: 59.36
# Removing pedestrian 449d28bf-fe58-40b5-a6fe-4824acc4a559 with only 40 points.
# Removing pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132 with only 2 points.
# Number of pedestrians after filtering: 5
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0088
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0088 asynchronously.
#
# Processing Scenario: 000, Frame: 0090
# Saved pedestrian PCD: saved_pedestrians\000_0088_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0088_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0088_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0088_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0088_ped_4.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0090
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0090
# Extracted 7 pedestrians in Scenario: 000, Frame: 0090
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 155.00
# Minimum point threshold set to: 77.50
# Removing pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132 with only 7 points.
# Number of pedestrians after filtering: 6
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0090
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0090 asynchronously.
#
# Processing Scenario: 000, Frame: 0092
# Saved pedestrian PCD: saved_pedestrians\000_0090_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0090_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0090_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0090_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0090_ped_4.ply
# Saved pedestrian PCD: saved_pedestrians\000_0090_ped_5.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0092
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0092
# Extracted 7 pedestrians in Scenario: 000, Frame: 0092
# Extracted 7 pedestrian point clouds.
# Average number of points per pedestrian PCD: 183.57
# Minimum point threshold set to: 91.79
# Removing pedestrian 967bd495-76fa-48f2-9053-c68b50b8d132 with only 6 points.
# Number of pedestrians after filtering: 6
# Prepared pedestrian PCD dictionary for Scenario: 000, Frame: 0092
# Started saving pedestrian PCDs for Scenario: 000, Frame: 0092 asynchronously.
#
# Processing Scenario: 000, Frame: 0094
# Saved pedestrian PCD: saved_pedestrians\000_0092_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\000_0092_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\000_0092_ped_2.ply
# Saved pedestrian PCD: saved_pedestrians\000_0092_ped_3.ply
# Saved pedestrian PCD: saved_pedestrians\000_0092_ped_4.ply
# Saved pedestrian PCD: saved_pedestrians\000_0092_ped_5.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 000, Frame: 0094
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 000, Frame: 0094
# Extracted 7 pedestrians in Scenario: 000, Frame: 0094
# ...
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0068 asynchronously.
#
# Processing Scenario: 026, Frame: 0070
# Saved pedestrian PCD: saved_pedestrians\026_0068_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0068_ped_1.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0070
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0070
# Extracted 4 pedestrians in Scenario: 026, Frame: 0070
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 278.75
# Minimum point threshold set to: 139.38
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 92 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 87 points.
# Number of pedestrians after filtering: 2
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0070
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0070 asynchronously.
#
# Processing Scenario: 026, Frame: 0072
# Saved pedestrian PCD: saved_pedestrians\026_0070_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0070_ped_1.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0072
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0072
# Extracted 4 pedestrians in Scenario: 026, Frame: 0072
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 257.25
# Minimum point threshold set to: 128.62
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 90 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 109 points.
# Number of pedestrians after filtering: 2
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0072
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0072 asynchronously.
#
# Processing Scenario: 026, Frame: 0074
# Saved pedestrian PCD: saved_pedestrians\026_0072_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0072_ped_1.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0074
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0074
# Extracted 4 pedestrians in Scenario: 026, Frame: 0074
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 273.25
# Minimum point threshold set to: 136.62
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 109 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 127 points.
# Number of pedestrians after filtering: 2
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0074
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0074 asynchronously.
#
# Processing Scenario: 026, Frame: 0076
# Saved pedestrian PCD: saved_pedestrians\026_0074_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0074_ped_1.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0076
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0076
# Extracted 4 pedestrians in Scenario: 026, Frame: 0076
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 277.75
# Minimum point threshold set to: 138.88
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 108 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 128 points.
# Number of pedestrians after filtering: 2
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0076
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0076 asynchronously.
#
# Processing Scenario: 026, Frame: 0078
# Saved pedestrian PCD: saved_pedestrians\026_0076_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0076_ped_1.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0078
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0078
# Extracted 4 pedestrians in Scenario: 026, Frame: 0078
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 267.75
# Minimum point threshold set to: 133.88
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 81 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0078
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0078 asynchronously.
#
# Processing Scenario: 026, Frame: 0080
# Saved pedestrian PCD: saved_pedestrians\026_0078_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0078_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0078_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0080
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0080
# Extracted 4 pedestrians in Scenario: 026, Frame: 0080
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 276.00
# Minimum point threshold set to: 138.00
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 87 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0080
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0080 asynchronously.
#
# Processing Scenario: 026, Frame: 0082
# Saved pedestrian PCD: saved_pedestrians\026_0080_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0080_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0080_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0082
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0082
# Extracted 4 pedestrians in Scenario: 026, Frame: 0082
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 253.75
# Minimum point threshold set to: 126.88
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 80 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0082
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0082 asynchronously.
#
# Processing Scenario: 026, Frame: 0084
# Saved pedestrian PCD: saved_pedestrians\026_0082_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0082_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0082_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0084
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0084
# Extracted 4 pedestrians in Scenario: 026, Frame: 0084
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 271.75
# Minimum point threshold set to: 135.88
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 82 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0084
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0084 asynchronously.
#
# Processing Scenario: 026, Frame: 0086
# Saved pedestrian PCD: saved_pedestrians\026_0084_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0084_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0084_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0086
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0086
# Extracted 4 pedestrians in Scenario: 026, Frame: 0086
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 253.00
# Minimum point threshold set to: 126.50
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 65 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0086
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0086 asynchronously.
#
# Processing Scenario: 026, Frame: 0088
# Saved pedestrian PCD: saved_pedestrians\026_0086_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0086_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0086_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0088
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0088
# Extracted 4 pedestrians in Scenario: 026, Frame: 0088
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 240.75
# Minimum point threshold set to: 120.38
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 24 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0088
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0088 asynchronously.
#
# Processing Scenario: 026, Frame: 0090
# Saved pedestrian PCD: saved_pedestrians\026_0088_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0088_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0088_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0090
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0090
# Extracted 4 pedestrians in Scenario: 026, Frame: 0090
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 267.00
# Minimum point threshold set to: 133.50
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 6 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0090
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0090 asynchronously.
#
# Processing Scenario: 026, Frame: 0092
# Saved pedestrian PCD: saved_pedestrians\026_0090_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0090_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0090_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0092
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0092
# Extracted 4 pedestrians in Scenario: 026, Frame: 0092
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 232.75
# Minimum point threshold set to: 116.38
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 0 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 97 points.
# Number of pedestrians after filtering: 2
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0092
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0092 asynchronously.
#
# Processing Scenario: 026, Frame: 0094
# Saved pedestrian PCD: saved_pedestrians\026_0092_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0092_ped_1.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0094
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0094
# Extracted 4 pedestrians in Scenario: 026, Frame: 0094
# Extracted 4 pedestrian point clouds.
# Average number of points per pedestrian PCD: 222.75
# Minimum point threshold set to: 111.38
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 0 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 37 points.
# Number of pedestrians after filtering: 2
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0094
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0094 asynchronously.
#
# Processing Scenario: 026, Frame: 0096
# Saved pedestrian PCD: saved_pedestrians\026_0094_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0094_ped_1.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0096
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0096
# Extracted 5 pedestrians in Scenario: 026, Frame: 0096
# Extracted 5 pedestrian point clouds.
# Average number of points per pedestrian PCD: 307.00
# Minimum point threshold set to: 153.50
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 13 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 11 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0096
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0096 asynchronously.
#
# Processing Scenario: 026, Frame: 0098
# Saved pedestrian PCD: saved_pedestrians\026_0096_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0096_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0096_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0098
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0098
# Extracted 5 pedestrians in Scenario: 026, Frame: 0098
# Extracted 5 pedestrian point clouds.
# Average number of points per pedestrian PCD: 294.60
# Minimum point threshold set to: 147.30
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 11 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 6 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0098
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0098 asynchronously.
#
# Processing Scenario: 026, Frame: 0100
# Saved pedestrian PCD: saved_pedestrians\026_0098_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0098_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0098_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0100
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0100
# Extracted 5 pedestrians in Scenario: 026, Frame: 0100
# Extracted 5 pedestrian point clouds.
# Average number of points per pedestrian PCD: 342.60
# Minimum point threshold set to: 171.30
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 32 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 19 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0100
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0100 asynchronously.
#
# Processing Scenario: 026, Frame: 0102
# Saved pedestrian PCD: saved_pedestrians\026_0100_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0100_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0100_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
# Retrieved sample for Scenario: 026, Frame: 0102
# Downsampling the point cloud...
# Removing statistical outliers...
# Preprocessed point cloud for Scenario: 026, Frame: 0102
# Extracted 5 pedestrians in Scenario: 026, Frame: 0102
# Extracted 5 pedestrian point clouds.
# Average number of points per pedestrian PCD: 352.20
# Minimum point threshold set to: 176.10
# Removing pedestrian 4ff8af4d-6840-47c2-bc9b-eb383009ad65 with only 51 points.
# Removing pedestrian 624e3a59-7b6f-4674-a223-41966cdfa39a with only 22 points.
# Number of pedestrians after filtering: 3
# Prepared pedestrian PCD dictionary for Scenario: 026, Frame: 0102
# Started saving pedestrian PCDs for Scenario: 026, Frame: 0102 asynchronously.
#
# Processing completed.
# Saved pedestrian PCD: saved_pedestrians\026_0102_ped_0.ply
# Saved pedestrian PCD: saved_pedestrians\026_0102_ped_1.ply
# Saved pedestrian PCD: saved_pedestrians\026_0102_ped_2.ply
# All pedestrian point clouds for the current frame have been saved.
